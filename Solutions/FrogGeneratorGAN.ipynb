# %% [markdown]
# <a href="https://colab.research.google.com/github/lmay1231/cosc470s24/blob/main/Solutions/FrogGeneratorGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# %%
def define_discriminator(input_shape=(32, 32, 3)):
    """
    Define the discriminator model structure for the DCGAN.

    Parameters:
    - input_shape: tuple, shape of the input images. Default is (32, 32, 3) for 32x32 RGB images.

    Returns:
    - Compiled Keras model of the discriminator.
    """
    model = Sequential()

    # Initial convolutional layer with input shape specification
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))

    # First downsample: reduces image dimensions by half, increases depth
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Second downsample
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Third downsample
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Flatten the output of the last convolutional layer
    model.add(Flatten())

    # Dropout for regularization (helps prevent overfitting)
    model.add(Dropout(0.4))

    # Output layer: binary classification (real or fake)
    model.add(Dense(1, activation='sigmoid'))

    # Compiling the model with Adam optimizer and binary crossentropy loss
    # Adjusted learning rate and beta_1 for stable training
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
def define_generator(latent_dim):
    """
    Define the generator model structure for the DCGAN.

    Parameters:
    - latent_dim: int, size of the latent space (noise vector input).

    Returns:
    - Uncompiled Keras model of the generator.
    """
    model = Sequential()

    # Foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))

    # Upsample to 8x8
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 16x16
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 32x32
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Output layer with tanh activation for generating images
    model.add(Conv2D(3, (3, 3), activation='tanh', padding='same'))

    return model

# %%
def define_gan(generator_model, discriminator_model):
    """
    Define the combined GAN model for training the generator.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN, set to non-trainable.

    Returns:
    - Compiled Keras model of the combined GAN, ready for training the generator.
    """
    # Set discriminator weights to non-trainable (only when part of the combined model)
    discriminator_model.trainable = False

    # Initialize the combined model
    model = Sequential()

    # Add generator
    model.add(generator_model)

    # Add discriminator
    model.add(discriminator_model)

    # Compile the combined model
    # The optimizer and loss function are set up for training the generator
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer)

    return model

# %%
def load_real_samples():
    """
    Load and prepare CIFAR-10 frog images.

    Returns:
    - X: numpy array, CIFAR-10 frog images normalized to [-1, 1].
    """
    # Load CIFAR-10 dataset
    (trainX, trainy), (_, _) = load_data()

    # Filter for frogs, which are class 6
    indices = np.where(trainy == 6)
    trainX = trainX[indices[0]]

    # Convert image data from unsigned integers to floats
    X = trainX.astype('float32')

    # Normalize the images from [0,255] to [-1,1]
    X = (X - 127.5) / 127.5

    return X

# Load the real samples for use
a = load_real_samples()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
def generate_real_samples(dataset, n_samples):
    """
    Select a random subset of real samples from a dataset.

    Parameters:
    - dataset: numpy array, the collection of images to select real samples from.
    - n_samples: int, the number of real samples to select.

    Returns:
    - X: numpy array, the selected images.
    - y: numpy array, an array of labels marking the selected images as real.
    """
    # Choose random instances
    ix = randint(0, dataset.shape[0], n_samples)

    # Retrieve selected images
    X = dataset[ix]

    # Generate 'real' class labels (1) for the selected samples
    y = ones((n_samples, 1))

    return X, y

# %%
def generate_latent_points(latent_dim, n_samples):
    """
    Generate points in the latent space as input for the generator.

    Parameters:
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate in the latent space.

    Returns:
    - x_input: numpy array, batch of latent points reshaped for the generator network.
    """
    # Generate points in the latent space
    x_input = randn(latent_dim * n_samples)

    # Reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)

    return x_input

# %%
def generate_fake_samples(generator_model, latent_dim, n_samples):
    """
    Use the generator to generate 'n' fake examples, along with their class labels.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of fake samples to generate.

    Returns:
    - X: numpy array, the generated fake images.
    - y: numpy array, an array of labels marking the images as fake.
    """
    # Generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)

    # Use the generator model to predict (generate) outputs
    X = generator_model.predict(x_input)

    # Create 'fake' class labels (0) for the generated images
    y = zeros((n_samples, 1))

    return X, y

# %%
def save_plot(examples, epoch, n=7):
    """
    Create and save a plot of generated images.

    Parameters:
    - examples: numpy array, the generated images to plot.
    - epoch: int, the current epoch number, used to name the saved file.
    - n: int, the number of images to display along each dimension of the grid. Default is 7.
    """
    # Scale from [-1,1] to [0,1] for plotting
    examples = (examples + 1) / 2.0

    # Plot images
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)
        # Turn off axis
        pyplot.axis('off')
        # Plot raw pixel data
        pyplot.imshow(examples[i])

    # Save plot to file
    filename = f'generated_plot_e{epoch+1:03d}.png'
    pyplot.savefig(filename)
    pyplot.close()

# %%
def summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=150):
    """
    Evaluate the discriminator, plot generated images, and save the generator model.

    Parameters:
    - epoch: int, the current training epoch.
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate for evaluation. Default is 150.
    """
    # Prepare real samples and evaluate discriminator on real examples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

    # Prepare fake examples and evaluate discriminator on fake examples
    x_fake, y_fake = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(x_fake, y_fake, verbose=0)

    # Summarize discriminator performance
    print(f'>Accuracy real: {acc_real*100:.0f}%, fake: {acc_fake*100:.0f}%')

    # Save plot of fake images
    save_plot(x_fake, epoch)

    # Save the generator model
    filename = f'generator_model_{epoch+1:03d}.h5'
    generator_model.save(filename)

# %%
def summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=150):
    """
    Evaluate the discriminator, plot generated images, and save the generator model.

    Parameters:
    - epoch: int, the current training epoch.
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate for evaluation. Default is 150.
    """
    # Prepare real samples and evaluate discriminator on real examples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

    # Prepare fake examples and evaluate discriminator on fake examples
    x_fake, y_fake = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(x_fake, y_fake, verbose=0)

    # Summarize discriminator performance
    print(f'>Accuracy real: {acc_real*100:.0f}%, fake: {acc_fake*100:.0f}%')

    # Save plot of fake images
    save_plot(x_fake, epoch)

    # Save the generator model
    filename = f'generator_model_{epoch+1:03d}.h5'
    generator_model.save(filename)

def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, n_epochs=200, n_batch=128):
    """
    Train the generator and discriminator of the GAN.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - gan_model: Model, the combined GAN model for updating the generator.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_epochs: int, the number of epochs to train for. Default is 200.
    - n_batch: int, the size of the batch. Default is 128.
    """
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)

    # Manually enumerate epochs
    for epoch in range(n_epochs):
        # Enumerate batches over the training set
        for batch in range(bat_per_epo):
            # Get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # Update discriminator model weights
            d_loss_real = discriminator_model.train_on_batch(X_real, y_real)[0]

            # Generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(generator_model, latent_dim, half_batch)
            # Update discriminator model weights
            d_loss_fake = discriminator_model.train_on_batch(X_fake, y_fake)[0]

            # Prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            # Create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            # Update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            # Summarize loss on this batch
            print(f'>{epoch+1}, {batch+1}/{bat_per_epo}, d_loss_real={d_loss_real:.3f}, d_loss_fake={d_loss_fake:.3f}, g_loss={g_loss:.3f}')

        # Evaluate the model performance, sometimes
        if (epoch + 1) % 10 == 0:
            summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim)

# %%
latent_dim = 100

# Create models
d_model = define_discriminator()
g_model = define_generator(latent_dim)
gan_model = define_gan(g_model, d_model)

# Load CIFAR-10 dataset
dataset = load_real_samples()

# Train model(s)
train(g_model, d_model, gan_model, dataset, latent_dim, 50)
# Out:
# 2/2 [==============================] - 0s 6ms/step
# >1, 1/39, d_loss_real=0.728, d_loss_fake=0.695, g_loss=0.692
# 2/2 [==============================] - 0s 5ms/step
# >1, 2/39, d_loss_real=0.659, d_loss_fake=0.697, g_loss=0.690
# 2/2 [==============================] - 0s 6ms/step
# >1, 3/39, d_loss_real=0.602, d_loss_fake=0.701, g_loss=0.686
# 2/2 [==============================] - 0s 4ms/step
# >1, 4/39, d_loss_real=0.518, d_loss_fake=0.710, g_loss=0.679
# 2/2 [==============================] - 0s 5ms/step
# >1, 5/39, d_loss_real=0.400, d_loss_fake=0.729, g_loss=0.666
# 2/2 [==============================] - 0s 4ms/step
# >1, 6/39, d_loss_real=0.290, d_loss_fake=0.757, g_loss=0.655
# 2/2 [==============================] - 0s 5ms/step
# >1, 7/39, d_loss_real=0.193, d_loss_fake=0.775, g_loss=0.664
# 2/2 [==============================] - 0s 4ms/step
# >1, 8/39, d_loss_real=0.135, d_loss_fake=0.756, g_loss=0.702
# 2/2 [==============================] - 0s 4ms/step
# >1, 9/39, d_loss_real=0.107, d_loss_fake=0.721, g_loss=0.753
# 2/2 [==============================] - 0s 5ms/step
# >1, 10/39, d_loss_real=0.089, d_loss_fake=0.702, g_loss=0.790
# 2/2 [==============================] - 0s 6ms/step
# >1, 11/39, d_loss_real=0.111, d_loss_fake=0.703, g_loss=0.810
# 2/2 [==============================] - 0s 7ms/step
# >1, 12/39, d_loss_real=0.123, d_loss_fake=0.702, g_loss=0.821
# 2/2 [==============================] - 0s 5ms/step
# >1, 13/39, d_loss_real=0.117, d_loss_fake=0.710, g_loss=0.818
# 2/2 [==============================] - 0s 4ms/step
# >1, 14/39, d_loss_real=0.087, d_loss_fake=0.716, g_loss=0.822
# 2/2 [==============================] - 0s 4ms/step
# >1, 15/39, d_loss_real=0.192, d_loss_fake=0.755, g_loss=0.802
# 2/2 [==============================] - 0s 4ms/step
# >1, 16/39, d_loss_real=0.191, d_loss_fake=0.850, g_loss=0.768
# 2/2 [==============================] - 0s 5ms/step
# >1, 17/39, d_loss_real=0.319, d_loss_fake=1.088, g_loss=0.653
# 2/2 [==============================] - 0s 5ms/step
# >1, 18/39, d_loss_real=0.351, d_loss_fake=1.170, g_loss=0.644
# 2/2 [==============================] - 0s 4ms/step
# >1, 19/39, d_loss_real=0.336, d_loss_fake=0.910, g_loss=0.813
# 2/2 [==============================] - 0s 5ms/step
# >1, 20/39, d_loss_real=0.405, d_loss_fake=0.645, g_loss=0.952
# 2/2 [==============================] - 0s 4ms/step
# >1, 21/39, d_loss_real=0.407, d_loss_fake=0.564, g_loss=0.977
# 2/2 [==============================] - 0s 5ms/step
# >1, 22/39, d_loss_real=0.329, d_loss_fake=0.557, g_loss=0.931
# 2/2 [==============================] - 0s 3ms/step
# >1, 23/39, d_loss_real=0.250, d_loss_fake=0.587, g_loss=0.877
# 2/2 [==============================] - 0s 4ms/step
# >1, 24/39, d_loss_real=0.225, d_loss_fake=0.623, g_loss=0.813
# 2/2 [==============================] - 0s 4ms/step
# >1, 25/39, d_loss_real=0.085, d_loss_fake=0.667, g_loss=0.785
# 2/2 [==============================] - 0s 4ms/step
# >1, 26/39, d_loss_real=0.085, d_loss_fake=0.779, g_loss=0.751
# 2/2 [==============================] - 0s 5ms/step
# >1, 27/39, d_loss_real=0.048, d_loss_fake=0.922, g_loss=0.677
# 2/2 [==============================] - 0s 5ms/step
# >1, 28/39, d_loss_real=0.049, d_loss_fake=0.993, g_loss=0.688
# 2/2 [==============================] - 0s 4ms/step
# >1, 29/39, d_loss_real=0.066, d_loss_fake=0.822, g_loss=0.813
# 2/2 [==============================] - 0s 4ms/step
# >1, 30/39, d_loss_real=0.071, d_loss_fake=0.671, g_loss=0.897
# 2/2 [==============================] - 0s 5ms/step
# >1, 31/39, d_loss_real=0.123, d_loss_fake=0.691, g_loss=0.794
# 2/2 [==============================] - 0s 4ms/step
# >1, 32/39, d_loss_real=0.156, d_loss_fake=0.802, g_loss=0.700
# 2/2 [==============================] - 0s 9ms/step
# >1, 33/39, d_loss_real=0.114, d_loss_fake=0.887, g_loss=0.668
# 2/2 [==============================] - 0s 4ms/step
# >1, 34/39, d_loss_real=0.091, d_loss_fake=0.897, g_loss=0.718
# 2/2 [==============================] - 0s 5ms/step
# >1, 35/39, d_loss_real=0.077, d_loss_fake=0.800, g_loss=0.835
# 2/2 [==============================] - 0s 4ms/step
# >1, 36/39, d_loss_real=0.123, d_loss_fake=0.663, g_loss=1.043
# 2/2 [==============================] - 0s 8ms/step
# >1, 37/39, d_loss_real=0.188, d_loss_fake=0.473, g_loss=1.353
# 2/2 [==============================] - 0s 4ms/step
# >1, 38/39, d_loss_real=0.243, d_loss_fake=0.374, g_loss=1.553
# 2/2 [==============================] - 0s 5ms/step
# >1, 39/39, d_loss_real=0.186, d_loss_fake=0.346, g_loss=1.618
# 2/2 [==============================] - 0s 5ms/step
# >2, 1/39, d_loss_real=0.241, d_loss_fake=0.397, g_loss=1.411
# 2/2 [==============================] - 0s 6ms/step
# >2, 2/39, d_loss_real=0.259, d_loss_fake=0.508, g_loss=1.178
# 2/2 [==============================] - 0s 5ms/step
# >2, 3/39, d_loss_real=0.170, d_loss_fake=0.561, g_loss=1.046
# 2/2 [==============================] - 0s 8ms/step
# >2, 4/39, d_loss_real=0.098, d_loss_fake=0.498, g_loss=1.142
# 2/2 [==============================] - 0s 4ms/step
# >2, 5/39, d_loss_real=0.137, d_loss_fake=0.457, g_loss=1.132
# 2/2 [==============================] - 0s 8ms/step
# >2, 6/39, d_loss_real=0.146, d_loss_fake=0.469, g_loss=1.073
# 2/2 [==============================] - 0s 4ms/step
# >2, 7/39, d_loss_real=0.041, d_loss_fake=0.495, g_loss=1.067
# 2/2 [==============================] - 0s 4ms/step
# >2, 8/39, d_loss_real=0.054, d_loss_fake=0.500, g_loss=1.065
# 2/2 [==============================] - 0s 4ms/step
# >2, 9/39, d_loss_real=0.087, d_loss_fake=0.501, g_loss=1.037
# 2/2 [==============================] - 0s 5ms/step
# >2, 10/39, d_loss_real=0.051, d_loss_fake=0.496, g_loss=1.061
# 2/2 [==============================] - 0s 6ms/step
# >2, 11/39, d_loss_real=0.053, d_loss_fake=0.471, g_loss=1.126
# 2/2 [==============================] - 0s 5ms/step
# >2, 12/39, d_loss_real=0.020, d_loss_fake=0.415, g_loss=1.238
# 2/2 [==============================] - 0s 5ms/step
# >2, 13/39, d_loss_real=0.038, d_loss_fake=0.366, g_loss=1.345
# 2/2 [==============================] - 0s 4ms/step
# >2, 14/39, d_loss_real=0.047, d_loss_fake=0.336, g_loss=1.432
# 2/2 [==============================] - 0s 5ms/step
# >2, 15/39, d_loss_real=0.053, d_loss_fake=0.315, g_loss=1.522
# 2/2 [==============================] - 0s 5ms/step
# >2, 16/39, d_loss_real=0.031, d_loss_fake=0.299, g_loss=1.597
# 2/2 [==============================] - 0s 5ms/step
# >2, 17/39, d_loss_real=0.016, d_loss_fake=0.318, g_loss=1.736
# 2/2 [==============================] - 0s 5ms/step
# >2, 18/39, d_loss_real=0.048, d_loss_fake=0.295, g_loss=1.995
# 2/2 [==============================] - 0s 5ms/step
# >2, 19/39, d_loss_real=0.109, d_loss_fake=0.217, g_loss=2.089
# 2/2 [==============================] - 0s 5ms/step
# >2, 20/39, d_loss_real=0.084, d_loss_fake=0.176, g_loss=2.130
# 2/2 [==============================] - 0s 5ms/step
# >2, 21/39, d_loss_real=0.011, d_loss_fake=0.158, g_loss=2.128
# 2/2 [==============================] - 0s 4ms/step
# >2, 22/39, d_loss_real=0.003, d_loss_fake=0.177, g_loss=1.994
# 2/2 [==============================] - 0s 4ms/step
# >2, 23/39, d_loss_real=0.011, d_loss_fake=0.427, g_loss=1.781
# 2/2 [==============================] - 0s 6ms/step
# >2, 24/39, d_loss_real=0.005, d_loss_fake=1.345, g_loss=3.601
# 2/2 [==============================] - 0s 4ms/step
# >2, 25/39, d_loss_real=0.391, d_loss_fake=0.047, g_loss=3.314
# 2/2 [==============================] - 0s 5ms/step
# >2, 26/39, d_loss_real=0.219, d_loss_fake=0.098, g_loss=2.393
# 2/2 [==============================] - 0s 5ms/step
# >2, 27/39, d_loss_real=0.050, d_loss_fake=0.222, g_loss=2.502
# 2/2 [==============================] - 0s 5ms/step
# >2, 28/39, d_loss_real=0.049, d_loss_fake=0.292, g_loss=3.947
# 2/2 [==============================] - 0s 6ms/step
# >2, 29/39, d_loss_real=0.243, d_loss_fake=0.074, g_loss=3.740
# 2/2 [==============================] - 0s 5ms/step
# >2, 30/39, d_loss_real=0.178, d_loss_fake=0.267, g_loss=5.383
# 2/2 [==============================] - 0s 4ms/step
# >2, 31/39, d_loss_real=0.368, d_loss_fake=0.022, g_loss=4.044
# 2/2 [==============================] - 0s 5ms/step
# >2, 32/39, d_loss_real=0.152, d_loss_fake=0.158, g_loss=2.878
# 2/2 [==============================] - 0s 4ms/step
# >2, 33/39, d_loss_real=0.099, d_loss_fake=0.301, g_loss=3.699
# 2/2 [==============================] - 0s 4ms/step
# >2, 34/39, d_loss_real=0.301, d_loss_fake=0.075, g_loss=3.133
# 2/2 [==============================] - 0s 4ms/step
# >2, 35/39, d_loss_real=0.096, d_loss_fake=0.139, g_loss=2.845
# 2/2 [==============================] - 0s 8ms/step
# >2, 36/39, d_loss_real=0.067, d_loss_fake=0.131, g_loss=3.016
# 2/2 [==============================] - 0s 5ms/step
# >2, 37/39, d_loss_real=0.093, d_loss_fake=0.198, g_loss=3.680
# 2/2 [==============================] - 0s 4ms/step
# >2, 38/39, d_loss_real=0.106, d_loss_fake=0.091, g_loss=3.225
# 2/2 [==============================] - 0s 3ms/step
# >2, 39/39, d_loss_real=0.032, d_loss_fake=0.386, g_loss=3.619
# 2/2 [==============================] - 0s 5ms/step
# >3, 1/39, d_loss_real=0.468, d_loss_fake=2.448, g_loss=4.049
# 2/2 [==============================] - 0s 5ms/step
# >3, 2/39, d_loss_real=0.146, d_loss_fake=0.004, g_loss=7.388
# 2/2 [==============================] - 0s 5ms/step
# >3, 3/39, d_loss_real=0.316, d_loss_fake=0.018, g_loss=4.086
# 2/2 [==============================] - 0s 4ms/step
# >3, 4/39, d_loss_real=0.309, d_loss_fake=1.423, g_loss=2.487
# 2/2 [==============================] - 0s 4ms/step
# >3, 5/39, d_loss_real=0.297, d_loss_fake=0.463, g_loss=4.129
# 2/2 [==============================] - 0s 4ms/step
# >3, 6/39, d_loss_real=1.506, d_loss_fake=0.664, g_loss=2.774
# 2/2 [==============================] - 0s 5ms/step
# >3, 7/39, d_loss_real=0.620, d_loss_fake=0.204, g_loss=2.927
# 2/2 [==============================] - 0s 5ms/step
# >3, 8/39, d_loss_real=0.607, d_loss_fake=0.495, g_loss=3.683
# 2/2 [==============================] - 0s 8ms/step
# >3, 9/39, d_loss_real=0.864, d_loss_fake=0.116, g_loss=2.481
# 2/2 [==============================] - 0s 3ms/step
# >3, 10/39, d_loss_real=0.374, d_loss_fake=0.474, g_loss=2.895
# 2/2 [==============================] - 0s 3ms/step
# >3, 11/39, d_loss_real=0.550, d_loss_fake=0.105, g_loss=2.874
# 2/2 [==============================] - 0s 5ms/step
# >3, 12/39, d_loss_real=0.679, d_loss_fake=0.215, g_loss=2.453
# 2/2 [==============================] - 0s 6ms/step
# >3, 13/39, d_loss_real=0.731, d_loss_fake=0.410, g_loss=3.181
# 2/2 [==============================] - 0s 5ms/step
# >3, 14/39, d_loss_real=0.588, d_loss_fake=0.046, g_loss=3.474
# 2/2 [==============================] - 0s 3ms/step
# >3, 15/39, d_loss_real=0.394, d_loss_fake=0.064, g_loss=2.922
# 2/2 [==============================] - 0s 5ms/step
# >3, 16/39, d_loss_real=0.203, d_loss_fake=0.314, g_loss=3.772
# 2/2 [==============================] - 0s 6ms/step
# >3, 17/39, d_loss_real=0.204, d_loss_fake=0.072, g_loss=3.799
# 2/2 [==============================] - 0s 6ms/step
# >3, 18/39, d_loss_real=0.303, d_loss_fake=1.230, g_loss=5.310
# 2/2 [==============================] - 0s 5ms/step
# >3, 19/39, d_loss_real=0.528, d_loss_fake=0.016, g_loss=5.288
# 2/2 [==============================] - 0s 4ms/step
# >3, 20/39, d_loss_real=0.610, d_loss_fake=0.103, g_loss=3.747
# 2/2 [==============================] - 0s 3ms/step
# >3, 21/39, d_loss_real=0.301, d_loss_fake=0.678, g_loss=7.879
# 2/2 [==============================] - 0s 3ms/step
# >3, 22/39, d_loss_real=0.567, d_loss_fake=0.003, g_loss=7.186
# 2/2 [==============================] - 0s 4ms/step
# >3, 23/39, d_loss_real=0.868, d_loss_fake=0.058, g_loss=2.963
# 2/2 [==============================] - 0s 5ms/step
# >3, 24/39, d_loss_real=0.388, d_loss_fake=0.186, g_loss=1.887
# 2/2 [==============================] - 0s 4ms/step
# >3, 25/39, d_loss_real=0.275, d_loss_fake=0.267, g_loss=1.700
# 2/2 [==============================] - 0s 5ms/step
# >3, 26/39, d_loss_real=0.084, d_loss_fake=0.293, g_loss=1.534
# 2/2 [==============================] - 0s 9ms/step
# >3, 27/39, d_loss_real=0.129, d_loss_fake=0.372, g_loss=1.578
# 2/2 [==============================] - 0s 5ms/step
# >3, 28/39, d_loss_real=0.139, d_loss_fake=0.473, g_loss=1.691
# 2/2 [==============================] - 0s 3ms/step
# >3, 29/39, d_loss_real=0.178, d_loss_fake=0.416, g_loss=1.721
# 2/2 [==============================] - 0s 5ms/step
# >3, 30/39, d_loss_real=0.091, d_loss_fake=0.492, g_loss=2.021
# 2/2 [==============================] - 0s 5ms/step
# >3, 31/39, d_loss_real=0.112, d_loss_fake=0.448, g_loss=2.285
# 2/2 [==============================] - 0s 4ms/step
# >3, 32/39, d_loss_real=0.242, d_loss_fake=0.343, g_loss=2.614
# 2/2 [==============================] - 0s 4ms/step
# >3, 33/39, d_loss_real=0.451, d_loss_fake=0.292, g_loss=2.431
# 2/2 [==============================] - 0s 5ms/step
# >3, 34/39, d_loss_real=0.617, d_loss_fake=0.383, g_loss=2.070
# 2/2 [==============================] - 0s 5ms/step
# >3, 35/39, d_loss_real=0.326, d_loss_fake=0.249, g_loss=2.245
# 2/2 [==============================] - 0s 4ms/step
# >3, 36/39, d_loss_real=0.413, d_loss_fake=0.255, g_loss=2.212
# 2/2 [==============================] - 0s 4ms/step
# >3, 37/39, d_loss_real=0.295, d_loss_fake=0.186, g_loss=2.385
# 2/2 [==============================] - 0s 4ms/step
# >3, 38/39, d_loss_real=0.187, d_loss_fake=0.138, g_loss=2.723
# 2/2 [==============================] - 0s 3ms/step
# >3, 39/39, d_loss_real=0.368, d_loss_fake=0.149, g_loss=2.635
# 2/2 [==============================] - 0s 4ms/step
# >4, 1/39, d_loss_real=0.342, d_loss_fake=0.209, g_loss=2.711
# 2/2 [==============================] - 0s 4ms/step
# >4, 2/39, d_loss_real=0.246, d_loss_fake=0.227, g_loss=3.213
# 2/2 [==============================] - 0s 6ms/step
# >4, 3/39, d_loss_real=0.398, d_loss_fake=0.150, g_loss=3.307
# 2/2 [==============================] - 0s 8ms/step
# >4, 4/39, d_loss_real=0.665, d_loss_fake=0.296, g_loss=3.156
# 2/2 [==============================] - 0s 9ms/step
# >4, 5/39, d_loss_real=0.395, d_loss_fake=0.142, g_loss=3.214
# 2/2 [==============================] - 0s 4ms/step
# >4, 6/39, d_loss_real=0.486, d_loss_fake=0.267, g_loss=2.805
# 2/2 [==============================] - 0s 6ms/step
# >4, 7/39, d_loss_real=0.490, d_loss_fake=0.280, g_loss=3.137
# 2/2 [==============================] - 0s 4ms/step
# >4, 8/39, d_loss_real=0.845, d_loss_fake=0.298, g_loss=2.595
# 2/2 [==============================] - 0s 5ms/step
# >4, 9/39, d_loss_real=0.731, d_loss_fake=0.586, g_loss=2.181
# 2/2 [==============================] - 0s 5ms/step
# >4, 10/39, d_loss_real=0.846, d_loss_fake=0.670, g_loss=1.952
# 2/2 [==============================] - 0s 9ms/step
# >4, 11/39, d_loss_real=0.638, d_loss_fake=0.309, g_loss=2.590
# 2/2 [==============================] - 0s 5ms/step
# >4, 12/39, d_loss_real=0.488, d_loss_fake=0.159, g_loss=3.011
# 2/2 [==============================] - 0s 5ms/step
# >4, 13/39, d_loss_real=0.353, d_loss_fake=0.194, g_loss=2.519
# 2/2 [==============================] - 0s 4ms/step
# >4, 14/39, d_loss_real=0.352, d_loss_fake=0.734, g_loss=1.843
# 2/2 [==============================] - 0s 6ms/step
# >4, 15/39, d_loss_real=0.490, d_loss_fake=0.558, g_loss=1.666
# 2/2 [==============================] - 0s 6ms/step
# >4, 16/39, d_loss_real=0.855, d_loss_fake=0.407, g_loss=1.926
# 2/2 [==============================] - 0s 4ms/step
# >4, 17/39, d_loss_real=0.613, d_loss_fake=0.240, g_loss=2.313
# 2/2 [==============================] - 0s 5ms/step
# >4, 18/39, d_loss_real=0.630, d_loss_fake=0.197, g_loss=2.271
# 2/2 [==============================] - 0s 5ms/step
# >4, 19/39, d_loss_real=0.515, d_loss_fake=0.201, g_loss=2.216
# 2/2 [==============================] - 0s 7ms/step
# >4, 20/39, d_loss_real=0.477, d_loss_fake=0.199, g_loss=2.170
# 2/2 [==============================] - 0s 5ms/step
# >4, 21/39, d_loss_real=0.649, d_loss_fake=0.220, g_loss=1.947
# 2/2 [==============================] - 0s 5ms/step
# >4, 22/39, d_loss_real=0.427, d_loss_fake=0.223, g_loss=1.992
# 2/2 [==============================] - 0s 6ms/step
# >4, 23/39, d_loss_real=0.463, d_loss_fake=0.228, g_loss=2.013
# 2/2 [==============================] - 0s 4ms/step
# >4, 24/39, d_loss_real=0.639, d_loss_fake=0.264, g_loss=1.755
# 2/2 [==============================] - 0s 5ms/step
# >4, 25/39, d_loss_real=0.409, d_loss_fake=0.251, g_loss=1.722
# 2/2 [==============================] - 0s 4ms/step
# >4, 26/39, d_loss_real=0.387, d_loss_fake=0.235, g_loss=1.730
# 2/2 [==============================] - 0s 5ms/step
# >4, 27/39, d_loss_real=0.372, d_loss_fake=0.241, g_loss=1.780
# 2/2 [==============================] - 0s 3ms/step
# >4, 28/39, d_loss_real=0.331, d_loss_fake=0.223, g_loss=1.807
# 2/2 [==============================] - 0s 4ms/step
# >4, 29/39, d_loss_real=0.314, d_loss_fake=0.216, g_loss=1.879
# 2/2 [==============================] - 0s 5ms/step
# >4, 30/39, d_loss_real=0.354, d_loss_fake=0.219, g_loss=1.829
# 2/2 [==============================] - 0s 5ms/step
# >4, 31/39, d_loss_real=0.255, d_loss_fake=0.217, g_loss=1.784
# 2/2 [==============================] - 0s 4ms/step
# >4, 32/39, d_loss_real=0.194, d_loss_fake=0.211, g_loss=1.816
# 2/2 [==============================] - 0s 5ms/step
# >4, 33/39, d_loss_real=0.395, d_loss_fake=0.299, g_loss=1.591
# 2/2 [==============================] - 0s 5ms/step
# >4, 34/39, d_loss_real=0.471, d_loss_fake=0.435, g_loss=1.369
# 2/2 [==============================] - 0s 5ms/step
# >4, 35/39, d_loss_real=0.257, d_loss_fake=0.632, g_loss=1.442
# 2/2 [==============================] - 0s 5ms/step
# >4, 36/39, d_loss_real=0.343, d_loss_fake=0.680, g_loss=2.423
# 2/2 [==============================] - 0s 4ms/step
# >4, 37/39, d_loss_real=0.394, d_loss_fake=0.212, g_loss=3.324
# 2/2 [==============================] - 0s 5ms/step
# >4, 38/39, d_loss_real=0.402, d_loss_fake=1.386, g_loss=4.791
# 2/2 [==============================] - 0s 5ms/step
# >4, 39/39, d_loss_real=0.841, d_loss_fake=0.316, g_loss=3.958
# 2/2 [==============================] - 0s 6ms/step
# >5, 1/39, d_loss_real=0.682, d_loss_fake=0.873, g_loss=3.993
# 2/2 [==============================] - 0s 6ms/step
# >5, 2/39, d_loss_real=1.269, d_loss_fake=0.237, g_loss=3.384
# 2/2 [==============================] - 0s 5ms/step
# >5, 3/39, d_loss_real=0.846, d_loss_fake=0.247, g_loss=2.611
# 2/2 [==============================] - 0s 3ms/step
# >5, 4/39, d_loss_real=1.005, d_loss_fake=0.396, g_loss=2.046
# 2/2 [==============================] - 0s 6ms/step
# >5, 5/39, d_loss_real=0.887, d_loss_fake=0.456, g_loss=1.897
# 2/2 [==============================] - 0s 4ms/step
# >5, 6/39, d_loss_real=0.391, d_loss_fake=0.306, g_loss=1.959
# 2/2 [==============================] - 0s 5ms/step
# >5, 7/39, d_loss_real=0.318, d_loss_fake=0.319, g_loss=1.877
# 2/2 [==============================] - 0s 3ms/step
# >5, 8/39, d_loss_real=0.406, d_loss_fake=0.337, g_loss=1.704
# 2/2 [==============================] - 0s 3ms/step
# >5, 9/39, d_loss_real=0.209, d_loss_fake=0.395, g_loss=1.684
# 2/2 [==============================] - 0s 3ms/step
# >5, 10/39, d_loss_real=0.266, d_loss_fake=0.347, g_loss=1.782
# 2/2 [==============================] - 0s 5ms/step
# >5, 11/39, d_loss_real=0.254, d_loss_fake=0.333, g_loss=1.895
# 2/2 [==============================] - 0s 3ms/step
# >5, 12/39, d_loss_real=0.341, d_loss_fake=0.299, g_loss=1.888
# 2/2 [==============================] - 0s 5ms/step
# >5, 13/39, d_loss_real=0.260, d_loss_fake=0.316, g_loss=1.982
# 2/2 [==============================] - 0s 4ms/step
# >5, 14/39, d_loss_real=0.266, d_loss_fake=0.281, g_loss=2.136
# 2/2 [==============================] - 0s 4ms/step
# >5, 15/39, d_loss_real=0.346, d_loss_fake=0.273, g_loss=2.184
# 2/2 [==============================] - 0s 5ms/step
# >5, 16/39, d_loss_real=0.402, d_loss_fake=0.344, g_loss=2.302
# 2/2 [==============================] - 0s 4ms/step
# >5, 17/39, d_loss_real=0.372, d_loss_fake=0.302, g_loss=2.591
# 2/2 [==============================] - 0s 6ms/step
# >5, 18/39, d_loss_real=0.400, d_loss_fake=0.351, g_loss=2.698
# 2/2 [==============================] - 0s 5ms/step
# >5, 19/39, d_loss_real=0.428, d_loss_fake=0.420, g_loss=3.220
# 2/2 [==============================] - 0s 4ms/step
# >5, 20/39, d_loss_real=0.555, d_loss_fake=0.378, g_loss=4.111
# 2/2 [==============================] - 0s 5ms/step
# >5, 21/39, d_loss_real=0.805, d_loss_fake=0.368, g_loss=4.516
# 2/2 [==============================] - 0s 4ms/step
# >5, 22/39, d_loss_real=0.905, d_loss_fake=0.652, g_loss=5.089
# 2/2 [==============================] - 0s 6ms/step
# >5, 23/39, d_loss_real=1.428, d_loss_fake=0.290, g_loss=3.162
# 2/2 [==============================] - 0s 4ms/step
# >5, 24/39, d_loss_real=1.095, d_loss_fake=1.135, g_loss=3.241
# 2/2 [==============================] - 0s 4ms/step
# >5, 25/39, d_loss_real=0.848, d_loss_fake=0.130, g_loss=2.967
# 2/2 [==============================] - 0s 5ms/step
# >5, 26/39, d_loss_real=0.596, d_loss_fake=0.300, g_loss=2.264
# 2/2 [==============================] - 0s 5ms/step
# >5, 27/39, d_loss_real=0.323, d_loss_fake=0.242, g_loss=2.500
# 2/2 [==============================] - 0s 5ms/step
# >5, 28/39, d_loss_real=0.343, d_loss_fake=0.163, g_loss=2.922
# 2/2 [==============================] - 0s 5ms/step
# >5, 29/39, d_loss_real=0.279, d_loss_fake=0.143, g_loss=2.851
# 2/2 [==============================] - 0s 4ms/step
# >5, 30/39, d_loss_real=0.326, d_loss_fake=0.200, g_loss=3.073
# 2/2 [==============================] - 0s 5ms/step
# >5, 31/39, d_loss_real=0.221, d_loss_fake=0.123, g_loss=3.297
# 2/2 [==============================] - 0s 5ms/step
# >5, 32/39, d_loss_real=0.282, d_loss_fake=0.125, g_loss=3.260
# 2/2 [==============================] - 0s 4ms/step
# >5, 33/39, d_loss_real=0.229, d_loss_fake=0.144, g_loss=3.440
# 2/2 [==============================] - 0s 4ms/step
# >5, 34/39, d_loss_real=0.243, d_loss_fake=0.139, g_loss=3.362
# 2/2 [==============================] - 0s 4ms/step
# >5, 35/39, d_loss_real=0.287, d_loss_fake=0.401, g_loss=3.946
# 2/2 [==============================] - 0s 4ms/step
# >5, 36/39, d_loss_real=0.447, d_loss_fake=0.207, g_loss=3.371
# 2/2 [==============================] - 0s 4ms/step
# >5, 37/39, d_loss_real=0.671, d_loss_fake=0.718, g_loss=3.847
# 2/2 [==============================] - 0s 5ms/step
# >5, 38/39, d_loss_real=0.875, d_loss_fake=0.162, g_loss=2.626
# 2/2 [==============================] - 0s 6ms/step
# >5, 39/39, d_loss_real=0.515, d_loss_fake=0.509, g_loss=2.510
# 2/2 [==============================] - 0s 4ms/step
# >6, 1/39, d_loss_real=0.500, d_loss_fake=0.187, g_loss=2.443
# 2/2 [==============================] - 0s 7ms/step
# >6, 2/39, d_loss_real=0.640, d_loss_fake=0.321, g_loss=2.096
# 2/2 [==============================] - 0s 4ms/step
# >6, 3/39, d_loss_real=0.368, d_loss_fake=0.302, g_loss=2.184
# 2/2 [==============================] - 0s 4ms/step
# >6, 4/39, d_loss_real=0.515, d_loss_fake=0.284, g_loss=2.176
# 2/2 [==============================] - 0s 4ms/step
# >6, 5/39, d_loss_real=0.354, d_loss_fake=0.258, g_loss=2.226
# 2/2 [==============================] - 0s 5ms/step
# >6, 6/39, d_loss_real=0.265, d_loss_fake=0.236, g_loss=2.233
# 2/2 [==============================] - 0s 7ms/step
# >6, 7/39, d_loss_real=0.289, d_loss_fake=0.289, g_loss=2.309
# 2/2 [==============================] - 0s 4ms/step
# >6, 8/39, d_loss_real=0.310, d_loss_fake=0.308, g_loss=2.531
# 2/2 [==============================] - 0s 9ms/step
# >6, 9/39, d_loss_real=0.345, d_loss_fake=0.225, g_loss=2.726
# 2/2 [==============================] - 0s 5ms/step
# >6, 10/39, d_loss_real=0.159, d_loss_fake=0.179, g_loss=3.112
# 2/2 [==============================] - 0s 4ms/step
# >6, 11/39, d_loss_real=0.268, d_loss_fake=0.115, g_loss=3.201
# 2/2 [==============================] - 0s 5ms/step
# >6, 12/39, d_loss_real=0.291, d_loss_fake=0.119, g_loss=3.225
# 2/2 [==============================] - 0s 4ms/step
# >6, 13/39, d_loss_real=0.199, d_loss_fake=0.119, g_loss=3.411
# 2/2 [==============================] - 0s 5ms/step
# >6, 14/39, d_loss_real=0.275, d_loss_fake=0.147, g_loss=3.376
# 2/2 [==============================] - 0s 4ms/step
# >6, 15/39, d_loss_real=0.280, d_loss_fake=0.152, g_loss=3.089
# 2/2 [==============================] - 0s 5ms/step
# >6, 16/39, d_loss_real=0.291, d_loss_fake=0.250, g_loss=2.933
# 2/2 [==============================] - 0s 5ms/step
# >6, 17/39, d_loss_real=0.348, d_loss_fake=0.397, g_loss=3.104
# 2/2 [==============================] - 0s 5ms/step
# >6, 18/39, d_loss_real=0.413, d_loss_fake=0.435, g_loss=3.678
# 2/2 [==============================] - 0s 5ms/step
# >6, 19/39, d_loss_real=0.974, d_loss_fake=0.438, g_loss=3.714
# 2/2 [==============================] - 0s 6ms/step
# >6, 20/39, d_loss_real=1.207, d_loss_fake=0.521, g_loss=4.069
# 2/2 [==============================] - 0s 5ms/step
# >6, 21/39, d_loss_real=1.853, d_loss_fake=0.210, g_loss=2.868
# 2/2 [==============================] - 0s 5ms/step
# >6, 22/39, d_loss_real=0.638, d_loss_fake=0.422, g_loss=3.947
# 2/2 [==============================] - 0s 4ms/step
# >6, 23/39, d_loss_real=0.941, d_loss_fake=0.107, g_loss=2.995
# 2/2 [==============================] - 0s 4ms/step
# >6, 24/39, d_loss_real=0.521, d_loss_fake=0.417, g_loss=3.910
# 2/2 [==============================] - 0s 5ms/step
# >6, 25/39, d_loss_real=0.727, d_loss_fake=0.071, g_loss=2.989
# 2/2 [==============================] - 0s 5ms/step
# >6, 26/39, d_loss_real=0.531, d_loss_fake=0.457, g_loss=3.154
# 2/2 [==============================] - 0s 5ms/step
# >6, 27/39, d_loss_real=0.635, d_loss_fake=0.150, g_loss=2.531
# 2/2 [==============================] - 0s 5ms/step
# >6, 28/39, d_loss_real=0.533, d_loss_fake=0.384, g_loss=2.262
# 2/2 [==============================] - 0s 5ms/step
# >6, 29/39, d_loss_real=0.555, d_loss_fake=0.278, g_loss=2.114
# 2/2 [==============================] - 0s 5ms/step
# >6, 30/39, d_loss_real=0.611, d_loss_fake=0.371, g_loss=2.024
# 2/2 [==============================] - 0s 5ms/step
# >6, 31/39, d_loss_real=0.536, d_loss_fake=0.332, g_loss=1.911
# 2/2 [==============================] - 0s 5ms/step
# >6, 32/39, d_loss_real=0.516, d_loss_fake=0.384, g_loss=1.681
# 2/2 [==============================] - 0s 5ms/step
# >6, 33/39, d_loss_real=0.585, d_loss_fake=0.444, g_loss=1.494
# 2/2 [==============================] - 0s 3ms/step
# >6, 34/39, d_loss_real=0.534, d_loss_fake=0.424, g_loss=1.381
# 2/2 [==============================] - 0s 4ms/step
# >6, 35/39, d_loss_real=0.425, d_loss_fake=0.587, g_loss=1.294
# 2/2 [==============================] - 0s 5ms/step
# >6, 36/39, d_loss_real=0.253, d_loss_fake=0.533, g_loss=1.449
# 2/2 [==============================] - 0s 5ms/step
# >6, 37/39, d_loss_real=0.457, d_loss_fake=0.587, g_loss=1.405
# 2/2 [==============================] - 0s 6ms/step
# >6, 38/39, d_loss_real=0.594, d_loss_fake=0.650, g_loss=1.201
# 2/2 [==============================] - 0s 5ms/step
# >6, 39/39, d_loss_real=0.385, d_loss_fake=0.548, g_loss=1.246
# 2/2 [==============================] - 0s 4ms/step
# >7, 1/39, d_loss_real=0.473, d_loss_fake=0.645, g_loss=1.443
# 2/2 [==============================] - 0s 5ms/step
# >7, 2/39, d_loss_real=0.395, d_loss_fake=0.406, g_loss=1.928
# 2/2 [==============================] - 0s 5ms/step
# >7, 3/39, d_loss_real=0.523, d_loss_fake=0.222, g_loss=2.122
# 2/2 [==============================] - 0s 3ms/step
# >7, 4/39, d_loss_real=0.239, d_loss_fake=0.171, g_loss=2.190
# 2/2 [==============================] - 0s 5ms/step
# >7, 5/39, d_loss_real=0.258, d_loss_fake=0.170, g_loss=2.297
# 2/2 [==============================] - 0s 5ms/step
# >7, 6/39, d_loss_real=0.274, d_loss_fake=0.169, g_loss=2.157
# 2/2 [==============================] - 0s 5ms/step
# >7, 7/39, d_loss_real=0.196, d_loss_fake=0.196, g_loss=2.083
# 2/2 [==============================] - 0s 6ms/step
# >7, 8/39, d_loss_real=0.139, d_loss_fake=0.207, g_loss=1.982
# 2/2 [==============================] - 0s 8ms/step
# >7, 9/39, d_loss_real=0.180, d_loss_fake=0.260, g_loss=1.788
# 2/2 [==============================] - 0s 4ms/step
# >7, 10/39, d_loss_real=0.135, d_loss_fake=0.274, g_loss=1.630
# 2/2 [==============================] - 0s 5ms/step
# >7, 11/39, d_loss_real=0.118, d_loss_fake=0.331, g_loss=1.526
# 2/2 [==============================] - 0s 4ms/step
# >7, 12/39, d_loss_real=0.156, d_loss_fake=0.351, g_loss=1.476
# 2/2 [==============================] - 0s 5ms/step
# >7, 13/39, d_loss_real=0.126, d_loss_fake=0.369, g_loss=1.455
# 2/2 [==============================] - 0s 6ms/step
# >7, 14/39, d_loss_real=0.156, d_loss_fake=0.354, g_loss=1.471
# 2/2 [==============================] - 0s 4ms/step
# >7, 15/39, d_loss_real=0.240, d_loss_fake=0.362, g_loss=1.585
# 2/2 [==============================] - 0s 5ms/step
# >7, 16/39, d_loss_real=0.200, d_loss_fake=0.285, g_loss=1.706
# 2/2 [==============================] - 0s 5ms/step
# >7, 17/39, d_loss_real=0.283, d_loss_fake=0.270, g_loss=1.700
# 2/2 [==============================] - 0s 4ms/step
# >7, 18/39, d_loss_real=0.210, d_loss_fake=0.292, g_loss=1.757
# 2/2 [==============================] - 0s 5ms/step
# >7, 19/39, d_loss_real=0.209, d_loss_fake=0.240, g_loss=1.889
# 2/2 [==============================] - 0s 5ms/step
# >7, 20/39, d_loss_real=0.210, d_loss_fake=0.225, g_loss=1.962
# 2/2 [==============================] - 0s 5ms/step
# >7, 21/39, d_loss_real=0.174, d_loss_fake=0.223, g_loss=2.098
# 2/2 [==============================] - 0s 5ms/step
# >7, 22/39, d_loss_real=0.295, d_loss_fake=0.231, g_loss=2.135
# 2/2 [==============================] - 0s 5ms/step
# >7, 23/39, d_loss_real=0.300, d_loss_fake=0.243, g_loss=2.091
# 2/2 [==============================] - 0s 5ms/step
# >7, 24/39, d_loss_real=0.243, d_loss_fake=0.260, g_loss=2.412
# 2/2 [==============================] - 0s 5ms/step
# >7, 25/39, d_loss_real=0.423, d_loss_fake=0.231, g_loss=2.328
# 2/2 [==============================] - 0s 4ms/step
# >7, 26/39, d_loss_real=0.266, d_loss_fake=0.328, g_loss=2.394
# 2/2 [==============================] - 0s 4ms/step
# >7, 27/39, d_loss_real=0.435, d_loss_fake=0.424, g_loss=2.805
# 2/2 [==============================] - 0s 4ms/step
# >7, 28/39, d_loss_real=0.508, d_loss_fake=0.210, g_loss=2.786
# 2/2 [==============================] - 0s 4ms/step
# >7, 29/39, d_loss_real=0.476, d_loss_fake=0.321, g_loss=3.043
# 2/2 [==============================] - 0s 4ms/step
# >7, 30/39, d_loss_real=0.457, d_loss_fake=0.147, g_loss=3.087
# 2/2 [==============================] - 0s 4ms/step
# >7, 31/39, d_loss_real=0.441, d_loss_fake=0.130, g_loss=2.910
# 2/2 [==============================] - 0s 6ms/step
# >7, 32/39, d_loss_real=0.532, d_loss_fake=0.252, g_loss=3.146
# 2/2 [==============================] - 0s 5ms/step
# >7, 33/39, d_loss_real=0.287, d_loss_fake=0.059, g_loss=3.439
# 2/2 [==============================] - 0s 4ms/step
# >7, 34/39, d_loss_real=0.759, d_loss_fake=0.206, g_loss=2.597
# 2/2 [==============================] - 0s 6ms/step
# >7, 35/39, d_loss_real=0.475, d_loss_fake=0.227, g_loss=2.699
# 2/2 [==============================] - 0s 10ms/step
# >7, 36/39, d_loss_real=0.422, d_loss_fake=0.126, g_loss=2.772
# 2/2 [==============================] - 0s 5ms/step
# >7, 37/39, d_loss_real=0.350, d_loss_fake=0.138, g_loss=2.651
# 2/2 [==============================] - 0s 7ms/step
# >7, 38/39, d_loss_real=0.312, d_loss_fake=0.147, g_loss=2.548
# 2/2 [==============================] - 0s 6ms/step
# >7, 39/39, d_loss_real=0.457, d_loss_fake=0.179, g_loss=2.277
# 2/2 [==============================] - 0s 10ms/step
# >8, 1/39, d_loss_real=0.495, d_loss_fake=0.243, g_loss=2.275
# 2/2 [==============================] - 0s 7ms/step
# >8, 2/39, d_loss_real=0.495, d_loss_fake=0.251, g_loss=2.234
# 2/2 [==============================] - 0s 6ms/step
# >8, 3/39, d_loss_real=0.552, d_loss_fake=0.305, g_loss=2.030
# 2/2 [==============================] - 0s 5ms/step
# >8, 4/39, d_loss_real=0.392, d_loss_fake=0.448, g_loss=2.003
# 2/2 [==============================] - 0s 5ms/step
# >8, 5/39, d_loss_real=0.367, d_loss_fake=0.297, g_loss=2.106
# 2/2 [==============================] - 0s 11ms/step
# >8, 6/39, d_loss_real=0.377, d_loss_fake=0.858, g_loss=2.610
# 2/2 [==============================] - 0s 7ms/step
# >8, 7/39, d_loss_real=0.785, d_loss_fake=3.480, g_loss=2.194
# 2/2 [==============================] - 0s 6ms/step
# >8, 8/39, d_loss_real=1.172, d_loss_fake=8.635, g_loss=2.405
# 2/2 [==============================] - 0s 5ms/step
# >8, 9/39, d_loss_real=1.209, d_loss_fake=2.137, g_loss=5.936
# 2/2 [==============================] - 0s 7ms/step
# >8, 10/39, d_loss_real=1.931, d_loss_fake=0.015, g_loss=6.445
# 2/2 [==============================] - 0s 6ms/step
# >8, 11/39, d_loss_real=1.625, d_loss_fake=0.067, g_loss=4.046
# 2/2 [==============================] - 0s 5ms/step
# >8, 12/39, d_loss_real=1.039, d_loss_fake=0.556, g_loss=6.980
# 2/2 [==============================] - 0s 7ms/step
# >8, 13/39, d_loss_real=1.416, d_loss_fake=0.011, g_loss=5.614
# 2/2 [==============================] - 0s 4ms/step
# >8, 14/39, d_loss_real=0.985, d_loss_fake=0.056, g_loss=3.066
# 2/2 [==============================] - 0s 5ms/step
# >8, 15/39, d_loss_real=0.711, d_loss_fake=0.361, g_loss=2.572
# 2/2 [==============================] - 0s 10ms/step
# >8, 16/39, d_loss_real=0.511, d_loss_fake=0.288, g_loss=2.781
# 2/2 [==============================] - 0s 6ms/step
# >8, 17/39, d_loss_real=0.470, d_loss_fake=0.238, g_loss=2.847
# 2/2 [==============================] - 0s 6ms/step
# >8, 18/39, d_loss_real=0.643, d_loss_fake=0.351, g_loss=2.072
# 2/2 [==============================] - 0s 4ms/step
# >8, 19/39, d_loss_real=0.508, d_loss_fake=0.407, g_loss=2.016
# 2/2 [==============================] - 0s 7ms/step
# >8, 20/39, d_loss_real=0.581, d_loss_fake=0.464, g_loss=1.895
# 2/2 [==============================] - 0s 6ms/step
# >8, 21/39, d_loss_real=0.615, d_loss_fake=0.505, g_loss=1.638
# 2/2 [==============================] - 0s 5ms/step
# >8, 22/39, d_loss_real=0.472, d_loss_fake=0.520, g_loss=1.546
# 2/2 [==============================] - 0s 8ms/step
# >8, 23/39, d_loss_real=0.520, d_loss_fake=0.519, g_loss=1.349
# 2/2 [==============================] - 0s 4ms/step
# >8, 24/39, d_loss_real=0.445, d_loss_fake=0.531, g_loss=1.323
# 2/2 [==============================] - 0s 5ms/step
# >8, 25/39, d_loss_real=0.436, d_loss_fake=0.473, g_loss=1.460
# 2/2 [==============================] - 0s 11ms/step
# >8, 26/39, d_loss_real=0.377, d_loss_fake=0.472, g_loss=1.444
# 2/2 [==============================] - 0s 4ms/step
# >8, 27/39, d_loss_real=0.529, d_loss_fake=0.388, g_loss=1.508
# 2/2 [==============================] - 0s 5ms/step
# >8, 28/39, d_loss_real=0.438, d_loss_fake=0.391, g_loss=1.632
# 2/2 [==============================] - 0s 5ms/step
# >8, 29/39, d_loss_real=0.324, d_loss_fake=0.345, g_loss=1.638
# 2/2 [==============================] - 0s 5ms/step
# >8, 30/39, d_loss_real=0.334, d_loss_fake=0.317, g_loss=1.752
# 2/2 [==============================] - 0s 5ms/step
# >8, 31/39, d_loss_real=0.276, d_loss_fake=0.304, g_loss=1.760
# 2/2 [==============================] - 0s 5ms/step
# >8, 32/39, d_loss_real=0.413, d_loss_fake=0.277, g_loss=1.735
# 2/2 [==============================] - 0s 5ms/step
# >8, 33/39, d_loss_real=0.315, d_loss_fake=0.279, g_loss=1.885
# 2/2 [==============================] - 0s 6ms/step
# >8, 34/39, d_loss_real=0.301, d_loss_fake=0.212, g_loss=1.875
# 2/2 [==============================] - 0s 5ms/step
# >8, 35/39, d_loss_real=0.398, d_loss_fake=0.287, g_loss=1.736
# 2/2 [==============================] - 0s 5ms/step
# >8, 36/39, d_loss_real=0.322, d_loss_fake=0.293, g_loss=1.716
# 2/2 [==============================] - 0s 5ms/step
# >8, 37/39, d_loss_real=0.376, d_loss_fake=0.336, g_loss=1.665
# 2/2 [==============================] - 0s 5ms/step
# >8, 38/39, d_loss_real=0.382, d_loss_fake=0.438, g_loss=1.363
# 2/2 [==============================] - 0s 5ms/step
# >8, 39/39, d_loss_real=0.420, d_loss_fake=0.485, g_loss=1.390
# 2/2 [==============================] - 0s 4ms/step
# >9, 1/39, d_loss_real=0.387, d_loss_fake=0.419, g_loss=1.341
# 2/2 [==============================] - 0s 6ms/step
# >9, 2/39, d_loss_real=0.311, d_loss_fake=0.481, g_loss=1.329
# 2/2 [==============================] - 0s 5ms/step
# >9, 3/39, d_loss_real=0.389, d_loss_fake=0.591, g_loss=1.182
# 2/2 [==============================] - 0s 5ms/step
# >9, 4/39, d_loss_real=0.440, d_loss_fake=0.576, g_loss=1.198
# 2/2 [==============================] - 0s 4ms/step
# >9, 5/39, d_loss_real=0.371, d_loss_fake=0.470, g_loss=1.265
# 2/2 [==============================] - 0s 5ms/step
# >9, 6/39, d_loss_real=0.321, d_loss_fake=0.431, g_loss=1.289
# 2/2 [==============================] - 0s 5ms/step
# >9, 7/39, d_loss_real=0.443, d_loss_fake=0.396, g_loss=1.314
# 2/2 [==============================] - 0s 11ms/step
# >9, 8/39, d_loss_real=0.507, d_loss_fake=0.395, g_loss=1.332
# 2/2 [==============================] - 0s 5ms/step
# >9, 9/39, d_loss_real=0.362, d_loss_fake=0.388, g_loss=1.398
# 2/2 [==============================] - 0s 5ms/step
# >9, 10/39, d_loss_real=0.311, d_loss_fake=0.394, g_loss=1.390
# 2/2 [==============================] - 0s 6ms/step
# >9, 11/39, d_loss_real=0.321, d_loss_fake=0.365, g_loss=1.451
# 2/2 [==============================] - 0s 5ms/step
# >9, 12/39, d_loss_real=0.281, d_loss_fake=0.427, g_loss=1.465
# 2/2 [==============================] - 0s 5ms/step
# >9, 13/39, d_loss_real=0.384, d_loss_fake=0.455, g_loss=1.416
# 2/2 [==============================] - 0s 5ms/step
# >9, 14/39, d_loss_real=0.267, d_loss_fake=0.477, g_loss=1.349
# 2/2 [==============================] - 0s 5ms/step
# >9, 15/39, d_loss_real=0.351, d_loss_fake=0.553, g_loss=1.528
# 2/2 [==============================] - 0s 5ms/step
# >9, 16/39, d_loss_real=0.463, d_loss_fake=0.465, g_loss=1.635
# 2/2 [==============================] - 0s 5ms/step
# >9, 17/39, d_loss_real=0.410, d_loss_fake=0.553, g_loss=1.790
# 2/2 [==============================] - 0s 4ms/step
# >9, 18/39, d_loss_real=0.681, d_loss_fake=0.471, g_loss=1.603
# 2/2 [==============================] - 0s 4ms/step
# >9, 19/39, d_loss_real=0.625, d_loss_fake=0.515, g_loss=1.531
# 2/2 [==============================] - 0s 6ms/step
# >9, 20/39, d_loss_real=0.687, d_loss_fake=0.424, g_loss=1.559
# 2/2 [==============================] - 0s 6ms/step
# >9, 21/39, d_loss_real=0.763, d_loss_fake=0.526, g_loss=1.393
# 2/2 [==============================] - 0s 4ms/step
# >9, 22/39, d_loss_real=0.577, d_loss_fake=0.441, g_loss=1.411
# 2/2 [==============================] - 0s 6ms/step
# >9, 23/39, d_loss_real=0.628, d_loss_fake=0.563, g_loss=1.459
# 2/2 [==============================] - 0s 7ms/step
# >9, 24/39, d_loss_real=0.472, d_loss_fake=0.501, g_loss=1.419
# 2/2 [==============================] - 0s 6ms/step
# >9, 25/39, d_loss_real=0.418, d_loss_fake=0.441, g_loss=1.418
# 2/2 [==============================] - 0s 5ms/step
# >9, 26/39, d_loss_real=0.525, d_loss_fake=0.515, g_loss=1.303
# 2/2 [==============================] - 0s 4ms/step
# >9, 27/39, d_loss_real=0.391, d_loss_fake=0.541, g_loss=1.349
# 2/2 [==============================] - 0s 4ms/step
# >9, 28/39, d_loss_real=0.467, d_loss_fake=0.401, g_loss=1.199
# 2/2 [==============================] - 0s 7ms/step
# >9, 29/39, d_loss_real=0.432, d_loss_fake=0.568, g_loss=1.231
# 2/2 [==============================] - 0s 5ms/step
# >9, 30/39, d_loss_real=0.382, d_loss_fake=0.617, g_loss=1.296
# 2/2 [==============================] - 0s 5ms/step
# >9, 31/39, d_loss_real=0.354, d_loss_fake=0.497, g_loss=1.336
# 2/2 [==============================] - 0s 5ms/step
# >9, 32/39, d_loss_real=0.391, d_loss_fake=0.583, g_loss=1.315
# 2/2 [==============================] - 0s 6ms/step
# >9, 33/39, d_loss_real=0.476, d_loss_fake=0.414, g_loss=1.180
# 2/2 [==============================] - 0s 9ms/step
# >9, 34/39, d_loss_real=0.282, d_loss_fake=0.514, g_loss=1.356
# 2/2 [==============================] - 0s 7ms/step
# >9, 35/39, d_loss_real=0.399, d_loss_fake=0.482, g_loss=1.446
# 2/2 [==============================] - 0s 5ms/step
# >9, 36/39, d_loss_real=0.553, d_loss_fake=0.526, g_loss=1.266
# 2/2 [==============================] - 0s 7ms/step
# >9, 37/39, d_loss_real=0.404, d_loss_fake=0.656, g_loss=1.308
# 2/2 [==============================] - 0s 5ms/step
# >9, 38/39, d_loss_real=0.363, d_loss_fake=0.545, g_loss=1.364
# 2/2 [==============================] - 0s 9ms/step
# >9, 39/39, d_loss_real=0.435, d_loss_fake=0.457, g_loss=1.355
# 2/2 [==============================] - 0s 5ms/step
# >10, 1/39, d_loss_real=0.387, d_loss_fake=0.426, g_loss=1.366
# 2/2 [==============================] - 0s 5ms/step
# >10, 2/39, d_loss_real=0.490, d_loss_fake=0.505, g_loss=1.373
# 2/2 [==============================] - 0s 5ms/step
# >10, 3/39, d_loss_real=0.452, d_loss_fake=0.502, g_loss=1.280
# 2/2 [==============================] - 0s 5ms/step
# >10, 4/39, d_loss_real=0.533, d_loss_fake=0.665, g_loss=1.200
# 2/2 [==============================] - 0s 5ms/step
# >10, 5/39, d_loss_real=0.463, d_loss_fake=0.567, g_loss=1.186
# 2/2 [==============================] - 0s 4ms/step
# >10, 6/39, d_loss_real=0.430, d_loss_fake=0.581, g_loss=1.161
# 2/2 [==============================] - 0s 6ms/step
# >10, 7/39, d_loss_real=0.451, d_loss_fake=0.573, g_loss=1.239
# 2/2 [==============================] - 0s 5ms/step
# >10, 8/39, d_loss_real=0.488, d_loss_fake=0.737, g_loss=1.035
# 2/2 [==============================] - 0s 5ms/step
# >10, 9/39, d_loss_real=0.584, d_loss_fake=0.762, g_loss=1.092
# 2/2 [==============================] - 0s 5ms/step
# >10, 10/39, d_loss_real=0.533, d_loss_fake=0.710, g_loss=1.024
# 2/2 [==============================] - 0s 5ms/step
# >10, 11/39, d_loss_real=0.431, d_loss_fake=0.872, g_loss=1.120
# 2/2 [==============================] - 0s 5ms/step
# >10, 12/39, d_loss_real=0.509, d_loss_fake=0.755, g_loss=1.082
# 2/2 [==============================] - 0s 5ms/step
# >10, 13/39, d_loss_real=0.499, d_loss_fake=0.621, g_loss=1.221
# 2/2 [==============================] - 0s 4ms/step
# >10, 14/39, d_loss_real=0.597, d_loss_fake=0.553, g_loss=1.420
# 2/2 [==============================] - 0s 5ms/step
# >10, 15/39, d_loss_real=0.474, d_loss_fake=0.368, g_loss=1.600
# 2/2 [==============================] - 0s 5ms/step
# >10, 16/39, d_loss_real=0.428, d_loss_fake=0.350, g_loss=1.740
# 2/2 [==============================] - 0s 5ms/step
# >10, 17/39, d_loss_real=0.432, d_loss_fake=0.262, g_loss=2.001
# 2/2 [==============================] - 0s 8ms/step
# >10, 18/39, d_loss_real=0.346, d_loss_fake=0.207, g_loss=2.057
# 2/2 [==============================] - 0s 6ms/step
# >10, 19/39, d_loss_real=0.332, d_loss_fake=0.212, g_loss=2.042
# 2/2 [==============================] - 0s 10ms/step
# >10, 20/39, d_loss_real=0.328, d_loss_fake=0.186, g_loss=2.068
# 2/2 [==============================] - 0s 4ms/step
# >10, 21/39, d_loss_real=0.331, d_loss_fake=0.204, g_loss=1.927
# 2/2 [==============================] - 0s 9ms/step
# >10, 22/39, d_loss_real=0.203, d_loss_fake=0.220, g_loss=1.785
# 2/2 [==============================] - 0s 5ms/step
# >10, 23/39, d_loss_real=0.209, d_loss_fake=0.297, g_loss=1.745
# 2/2 [==============================] - 0s 6ms/step
# >10, 24/39, d_loss_real=0.197, d_loss_fake=0.361, g_loss=1.584
# 2/2 [==============================] - 0s 5ms/step
# >10, 25/39, d_loss_real=0.234, d_loss_fake=0.461, g_loss=1.413
# 2/2 [==============================] - 0s 6ms/step
# >10, 26/39, d_loss_real=0.258, d_loss_fake=0.540, g_loss=1.341
# 2/2 [==============================] - 0s 5ms/step
# >10, 27/39, d_loss_real=0.425, d_loss_fake=0.634, g_loss=1.192
# 2/2 [==============================] - 0s 5ms/step
# >10, 28/39, d_loss_real=0.292, d_loss_fake=0.847, g_loss=1.294
# 2/2 [==============================] - 0s 5ms/step
# >10, 29/39, d_loss_real=0.449, d_loss_fake=0.585, g_loss=1.409
# 2/2 [==============================] - 0s 4ms/step
# >10, 30/39, d_loss_real=0.572, d_loss_fake=0.651, g_loss=1.550
# 2/2 [==============================] - 0s 7ms/step
# >10, 31/39, d_loss_real=0.856, d_loss_fake=0.563, g_loss=1.528
# 2/2 [==============================] - 0s 3ms/step
# >10, 32/39, d_loss_real=0.828, d_loss_fake=0.478, g_loss=1.621
# 2/2 [==============================] - 0s 5ms/step
# >10, 33/39, d_loss_real=0.823, d_loss_fake=0.443, g_loss=1.939
# 2/2 [==============================] - 0s 5ms/step
# >10, 34/39, d_loss_real=0.997, d_loss_fake=0.356, g_loss=1.991
# 2/2 [==============================] - 0s 5ms/step
# >10, 35/39, d_loss_real=0.927, d_loss_fake=0.238, g_loss=1.936
# 2/2 [==============================] - 0s 4ms/step
# >10, 36/39, d_loss_real=0.851, d_loss_fake=0.245, g_loss=2.039
# 2/2 [==============================] - 0s 5ms/step
# >10, 37/39, d_loss_real=0.723, d_loss_fake=0.278, g_loss=2.062
# 2/2 [==============================] - 0s 5ms/step
# >10, 38/39, d_loss_real=0.641, d_loss_fake=0.256, g_loss=2.164
# 2/2 [==============================] - 0s 5ms/step
# >10, 39/39, d_loss_real=0.554, d_loss_fake=0.167, g_loss=2.323
# 5/5 [==============================] - 0s 57ms/step
# >Accuracy real: 65%, fake: 99%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 [==============================] - 0s 5ms/step
# >11, 1/39, d_loss_real=0.627, d_loss_fake=0.224, g_loss=2.174
# 2/2 [==============================] - 0s 4ms/step
# >11, 2/39, d_loss_real=0.529, d_loss_fake=0.207, g_loss=2.212
# 2/2 [==============================] - 0s 3ms/step
# >11, 3/39, d_loss_real=0.558, d_loss_fake=0.242, g_loss=2.213
# 2/2 [==============================] - 0s 5ms/step
# >11, 4/39, d_loss_real=0.511, d_loss_fake=0.236, g_loss=2.144
# 2/2 [==============================] - 0s 4ms/step
# >11, 5/39, d_loss_real=0.336, d_loss_fake=0.273, g_loss=2.188
# 2/2 [==============================] - 0s 4ms/step
# >11, 6/39, d_loss_real=0.432, d_loss_fake=0.253, g_loss=2.206
# 2/2 [==============================] - 0s 5ms/step
# >11, 7/39, d_loss_real=0.281, d_loss_fake=0.268, g_loss=2.108
# 2/2 [==============================] - 0s 8ms/step
# >11, 8/39, d_loss_real=0.342, d_loss_fake=0.417, g_loss=1.684
# 2/2 [==============================] - 0s 4ms/step
# >11, 9/39, d_loss_real=0.347, d_loss_fake=0.412, g_loss=1.673
# 2/2 [==============================] - 0s 4ms/step
# >11, 10/39, d_loss_real=0.427, d_loss_fake=0.487, g_loss=1.277
# 2/2 [==============================] - 0s 6ms/step
# >11, 11/39, d_loss_real=0.389, d_loss_fake=0.580, g_loss=1.195
# 2/2 [==============================] - 0s 5ms/step
# >11, 12/39, d_loss_real=0.620, d_loss_fake=0.568, g_loss=1.050
# 2/2 [==============================] - 0s 6ms/step
# >11, 13/39, d_loss_real=0.333, d_loss_fake=0.580, g_loss=1.140
# 2/2 [==============================] - 0s 5ms/step
# >11, 14/39, d_loss_real=0.409, d_loss_fake=0.594, g_loss=1.133
# 2/2 [==============================] - 0s 4ms/step
# >11, 15/39, d_loss_real=0.481, d_loss_fake=0.546, g_loss=1.123
# 2/2 [==============================] - 0s 5ms/step
# >11, 16/39, d_loss_real=0.526, d_loss_fake=0.571, g_loss=1.150
# 2/2 [==============================] - 0s 5ms/step
# >11, 17/39, d_loss_real=0.403, d_loss_fake=0.528, g_loss=1.091
# 2/2 [==============================] - 0s 5ms/step
# >11, 18/39, d_loss_real=0.498, d_loss_fake=0.538, g_loss=1.096
# 2/2 [==============================] - 0s 5ms/step
# >11, 19/39, d_loss_real=0.329, d_loss_fake=0.546, g_loss=1.072
# 2/2 [==============================] - 0s 5ms/step
# >11, 20/39, d_loss_real=0.265, d_loss_fake=0.586, g_loss=1.126
# 2/2 [==============================] - 0s 5ms/step
# >11, 21/39, d_loss_real=0.433, d_loss_fake=0.591, g_loss=1.109
# 2/2 [==============================] - 0s 6ms/step
# >11, 22/39, d_loss_real=0.443, d_loss_fake=0.543, g_loss=1.177
# 2/2 [==============================] - 0s 5ms/step
# >11, 23/39, d_loss_real=0.341, d_loss_fake=0.532, g_loss=1.255
# 2/2 [==============================] - 0s 6ms/step
# >11, 24/39, d_loss_real=0.426, d_loss_fake=0.437, g_loss=1.385
# 2/2 [==============================] - 0s 7ms/step
# >11, 25/39, d_loss_real=0.355, d_loss_fake=0.357, g_loss=1.420
# 2/2 [==============================] - 0s 7ms/step
# >11, 26/39, d_loss_real=0.334, d_loss_fake=0.330, g_loss=1.612
# 2/2 [==============================] - 0s 6ms/step
# >11, 27/39, d_loss_real=0.284, d_loss_fake=0.319, g_loss=1.732
# 2/2 [==============================] - 0s 5ms/step
# >11, 28/39, d_loss_real=0.367, d_loss_fake=0.274, g_loss=1.847
# 2/2 [==============================] - 0s 5ms/step
# >11, 29/39, d_loss_real=0.325, d_loss_fake=0.282, g_loss=1.785
# 2/2 [==============================] - 0s 5ms/step
# >11, 30/39, d_loss_real=0.355, d_loss_fake=0.296, g_loss=1.946
# ...
# 2/2 [==============================] - 0s 5ms/step
# >47, 19/39, d_loss_real=0.579, d_loss_fake=0.571, g_loss=1.046
# 2/2 [==============================] - 0s 6ms/step
# >47, 20/39, d_loss_real=0.592, d_loss_fake=0.589, g_loss=1.007
# 2/2 [==============================] - 0s 5ms/step
# >47, 21/39, d_loss_real=0.572, d_loss_fake=0.650, g_loss=1.154
# 2/2 [==============================] - 0s 4ms/step
# >47, 22/39, d_loss_real=0.593, d_loss_fake=0.568, g_loss=1.176
# 2/2 [==============================] - 0s 5ms/step
# >47, 23/39, d_loss_real=0.559, d_loss_fake=0.520, g_loss=1.274
# 2/2 [==============================] - 0s 4ms/step
# >47, 24/39, d_loss_real=0.595, d_loss_fake=0.503, g_loss=1.242
# 2/2 [==============================] - 0s 5ms/step
# >47, 25/39, d_loss_real=0.551, d_loss_fake=0.456, g_loss=1.218
# 2/2 [==============================] - 0s 4ms/step
# >47, 26/39, d_loss_real=0.502, d_loss_fake=0.565, g_loss=1.267
# 2/2 [==============================] - 0s 6ms/step
# >47, 27/39, d_loss_real=0.565, d_loss_fake=0.547, g_loss=1.217
# 2/2 [==============================] - 0s 5ms/step
# >47, 28/39, d_loss_real=0.479, d_loss_fake=0.578, g_loss=1.290
# 2/2 [==============================] - 0s 5ms/step
# >47, 29/39, d_loss_real=0.504, d_loss_fake=0.691, g_loss=1.251
# 2/2 [==============================] - 0s 8ms/step
# >47, 30/39, d_loss_real=0.650, d_loss_fake=0.847, g_loss=1.259
# 2/2 [==============================] - 0s 4ms/step
# >47, 31/39, d_loss_real=0.738, d_loss_fake=0.851, g_loss=1.118
# 2/2 [==============================] - 0s 6ms/step
# >47, 32/39, d_loss_real=0.878, d_loss_fake=0.671, g_loss=1.183
# 2/2 [==============================] - 0s 4ms/step
# >47, 33/39, d_loss_real=0.762, d_loss_fake=0.716, g_loss=1.190
# 2/2 [==============================] - 0s 5ms/step
# >47, 34/39, d_loss_real=0.806, d_loss_fake=0.622, g_loss=1.375
# 2/2 [==============================] - 0s 4ms/step
# >47, 35/39, d_loss_real=0.736, d_loss_fake=0.510, g_loss=1.264
# 2/2 [==============================] - 0s 4ms/step
# >47, 36/39, d_loss_real=0.694, d_loss_fake=0.544, g_loss=1.378
# 2/2 [==============================] - 0s 5ms/step
# >47, 37/39, d_loss_real=0.631, d_loss_fake=0.534, g_loss=1.346
# 2/2 [==============================] - 0s 5ms/step
# >47, 38/39, d_loss_real=0.555, d_loss_fake=0.476, g_loss=1.376
# 2/2 [==============================] - 0s 5ms/step
# >47, 39/39, d_loss_real=0.702, d_loss_fake=0.457, g_loss=1.361
# 2/2 [==============================] - 0s 4ms/step
# >48, 1/39, d_loss_real=0.570, d_loss_fake=0.474, g_loss=1.251
# 2/2 [==============================] - 0s 4ms/step
# >48, 2/39, d_loss_real=0.584, d_loss_fake=0.541, g_loss=1.225
# 2/2 [==============================] - 0s 4ms/step
# >48, 3/39, d_loss_real=0.571, d_loss_fake=0.520, g_loss=1.122
# 2/2 [==============================] - 0s 4ms/step
# >48, 4/39, d_loss_real=0.511, d_loss_fake=0.584, g_loss=1.090
# 2/2 [==============================] - 0s 4ms/step
# >48, 5/39, d_loss_real=0.459, d_loss_fake=0.544, g_loss=1.129
# 2/2 [==============================] - 0s 5ms/step
# >48, 6/39, d_loss_real=0.584, d_loss_fake=0.628, g_loss=1.073
# 2/2 [==============================] - 0s 4ms/step
# >48, 7/39, d_loss_real=0.561, d_loss_fake=0.587, g_loss=1.029
# 2/2 [==============================] - 0s 4ms/step
# >48, 8/39, d_loss_real=0.595, d_loss_fake=0.590, g_loss=0.978
# 2/2 [==============================] - 0s 5ms/step
# >48, 9/39, d_loss_real=0.566, d_loss_fake=0.645, g_loss=0.990
# 2/2 [==============================] - 0s 5ms/step
# >48, 10/39, d_loss_real=0.633, d_loss_fake=0.672, g_loss=0.986
# 2/2 [==============================] - 0s 4ms/step
# >48, 11/39, d_loss_real=0.630, d_loss_fake=0.632, g_loss=1.001
# 2/2 [==============================] - 0s 4ms/step
# >48, 12/39, d_loss_real=0.643, d_loss_fake=0.623, g_loss=1.084
# 2/2 [==============================] - 0s 4ms/step
# >48, 13/39, d_loss_real=0.759, d_loss_fake=0.630, g_loss=1.067
# 2/2 [==============================] - 0s 4ms/step
# >48, 14/39, d_loss_real=0.647, d_loss_fake=0.641, g_loss=1.146
# 2/2 [==============================] - 0s 9ms/step
# >48, 15/39, d_loss_real=0.612, d_loss_fake=0.582, g_loss=1.134
# 2/2 [==============================] - 0s 4ms/step
# >48, 16/39, d_loss_real=0.668, d_loss_fake=0.650, g_loss=1.058
# 2/2 [==============================] - 0s 4ms/step
# >48, 17/39, d_loss_real=0.646, d_loss_fake=0.649, g_loss=1.051
# 2/2 [==============================] - 0s 4ms/step
# >48, 18/39, d_loss_real=0.674, d_loss_fake=0.625, g_loss=1.025
# 2/2 [==============================] - 0s 4ms/step
# >48, 19/39, d_loss_real=0.697, d_loss_fake=0.649, g_loss=1.056
# 2/2 [==============================] - 0s 12ms/step
# >48, 20/39, d_loss_real=0.662, d_loss_fake=0.604, g_loss=0.999
# 2/2 [==============================] - 0s 4ms/step
# >48, 21/39, d_loss_real=0.612, d_loss_fake=0.603, g_loss=1.083
# 2/2 [==============================] - 0s 5ms/step
# >48, 22/39, d_loss_real=0.657, d_loss_fake=0.545, g_loss=1.124
# 2/2 [==============================] - 0s 8ms/step
# >48, 23/39, d_loss_real=0.606, d_loss_fake=0.537, g_loss=1.076
# 2/2 [==============================] - 0s 5ms/step
# >48, 24/39, d_loss_real=0.598, d_loss_fake=0.520, g_loss=1.136
# 2/2 [==============================] - 0s 5ms/step
# >48, 25/39, d_loss_real=0.578, d_loss_fake=0.554, g_loss=1.094
# 2/2 [==============================] - 0s 5ms/step
# >48, 26/39, d_loss_real=0.637, d_loss_fake=0.652, g_loss=1.121
# 2/2 [==============================] - 0s 5ms/step
# >48, 27/39, d_loss_real=0.593, d_loss_fake=0.641, g_loss=1.083
# 2/2 [==============================] - 0s 5ms/step
# >48, 28/39, d_loss_real=0.685, d_loss_fake=0.643, g_loss=1.128
# 2/2 [==============================] - 0s 5ms/step
# >48, 29/39, d_loss_real=0.689, d_loss_fake=0.591, g_loss=1.100
# 2/2 [==============================] - 0s 5ms/step
# >48, 30/39, d_loss_real=0.616, d_loss_fake=0.634, g_loss=1.070
# 2/2 [==============================] - 0s 4ms/step
# >48, 31/39, d_loss_real=0.650, d_loss_fake=0.539, g_loss=1.129
# 2/2 [==============================] - 0s 6ms/step
# >48, 32/39, d_loss_real=0.677, d_loss_fake=0.584, g_loss=1.066
# 2/2 [==============================] - 0s 5ms/step
# >48, 33/39, d_loss_real=0.685, d_loss_fake=0.663, g_loss=0.986
# 2/2 [==============================] - 0s 5ms/step
# >48, 34/39, d_loss_real=0.719, d_loss_fake=0.675, g_loss=1.061
# 2/2 [==============================] - 0s 4ms/step
# >48, 35/39, d_loss_real=0.633, d_loss_fake=0.554, g_loss=1.130
# 2/2 [==============================] - 0s 4ms/step
# >48, 36/39, d_loss_real=0.705, d_loss_fake=0.555, g_loss=1.134
# 2/2 [==============================] - 0s 4ms/step
# >48, 37/39, d_loss_real=0.667, d_loss_fake=0.521, g_loss=1.090
# 2/2 [==============================] - 0s 5ms/step
# >48, 38/39, d_loss_real=0.666, d_loss_fake=0.586, g_loss=1.152
# 2/2 [==============================] - 0s 4ms/step
# >48, 39/39, d_loss_real=0.663, d_loss_fake=0.556, g_loss=1.143
# 2/2 [==============================] - 0s 6ms/step
# >49, 1/39, d_loss_real=0.609, d_loss_fake=0.548, g_loss=1.208
# 2/2 [==============================] - 0s 5ms/step
# >49, 2/39, d_loss_real=0.674, d_loss_fake=0.451, g_loss=1.291
# 2/2 [==============================] - 0s 6ms/step
# >49, 3/39, d_loss_real=0.620, d_loss_fake=0.427, g_loss=1.224
# 2/2 [==============================] - 0s 5ms/step
# >49, 4/39, d_loss_real=0.589, d_loss_fake=0.518, g_loss=1.225
# 2/2 [==============================] - 0s 5ms/step
# >49, 5/39, d_loss_real=0.538, d_loss_fake=0.504, g_loss=1.283
# 2/2 [==============================] - 0s 4ms/step
# >49, 6/39, d_loss_real=0.570, d_loss_fake=0.468, g_loss=1.294
# 2/2 [==============================] - 0s 5ms/step
# >49, 7/39, d_loss_real=0.557, d_loss_fake=0.542, g_loss=1.286
# 2/2 [==============================] - 0s 5ms/step
# >49, 8/39, d_loss_real=0.634, d_loss_fake=0.521, g_loss=1.257
# 2/2 [==============================] - 0s 5ms/step
# >49, 9/39, d_loss_real=0.583, d_loss_fake=0.489, g_loss=1.314
# 2/2 [==============================] - 0s 4ms/step
# >49, 10/39, d_loss_real=0.634, d_loss_fake=0.448, g_loss=1.313
# 2/2 [==============================] - 0s 4ms/step
# >49, 11/39, d_loss_real=0.599, d_loss_fake=0.449, g_loss=1.198
# 2/2 [==============================] - 0s 5ms/step
# >49, 12/39, d_loss_real=0.567, d_loss_fake=0.577, g_loss=1.253
# 2/2 [==============================] - 0s 5ms/step
# >49, 13/39, d_loss_real=0.560, d_loss_fake=0.472, g_loss=1.265
# 2/2 [==============================] - 0s 5ms/step
# >49, 14/39, d_loss_real=0.647, d_loss_fake=0.508, g_loss=1.279
# 2/2 [==============================] - 0s 5ms/step
# >49, 15/39, d_loss_real=0.640, d_loss_fake=0.479, g_loss=1.306
# 2/2 [==============================] - 0s 8ms/step
# >49, 16/39, d_loss_real=0.624, d_loss_fake=0.483, g_loss=1.292
# 2/2 [==============================] - 0s 4ms/step
# >49, 17/39, d_loss_real=0.712, d_loss_fake=0.483, g_loss=1.235
# 2/2 [==============================] - 0s 9ms/step
# >49, 18/39, d_loss_real=0.566, d_loss_fake=0.454, g_loss=1.315
# 2/2 [==============================] - 0s 4ms/step
# >49, 19/39, d_loss_real=0.633, d_loss_fake=0.484, g_loss=1.396
# 2/2 [==============================] - 0s 5ms/step
# >49, 20/39, d_loss_real=0.662, d_loss_fake=0.456, g_loss=1.335
# 2/2 [==============================] - 0s 6ms/step
# >49, 21/39, d_loss_real=0.638, d_loss_fake=0.392, g_loss=1.367
# 2/2 [==============================] - 0s 4ms/step
# >49, 22/39, d_loss_real=0.574, d_loss_fake=0.525, g_loss=1.302
# 2/2 [==============================] - 0s 7ms/step
# >49, 23/39, d_loss_real=0.560, d_loss_fake=0.516, g_loss=1.197
# 2/2 [==============================] - 0s 7ms/step
# >49, 24/39, d_loss_real=0.512, d_loss_fake=0.575, g_loss=1.251
# 2/2 [==============================] - 0s 4ms/step
# >49, 25/39, d_loss_real=0.644, d_loss_fake=0.534, g_loss=1.193
# 2/2 [==============================] - 0s 7ms/step
# >49, 26/39, d_loss_real=0.590, d_loss_fake=0.641, g_loss=1.165
# 2/2 [==============================] - 0s 5ms/step
# >49, 27/39, d_loss_real=0.557, d_loss_fake=0.525, g_loss=1.151
# 2/2 [==============================] - 0s 9ms/step
# >49, 28/39, d_loss_real=0.541, d_loss_fake=0.555, g_loss=1.156
# 2/2 [==============================] - 0s 5ms/step
# >49, 29/39, d_loss_real=0.536, d_loss_fake=0.708, g_loss=1.244
# 2/2 [==============================] - 0s 5ms/step
# >49, 30/39, d_loss_real=0.567, d_loss_fake=0.587, g_loss=1.207
# 2/2 [==============================] - 0s 5ms/step
# >49, 31/39, d_loss_real=0.584, d_loss_fake=0.588, g_loss=1.063
# 2/2 [==============================] - 0s 4ms/step
# >49, 32/39, d_loss_real=0.662, d_loss_fake=0.636, g_loss=0.998
# 2/2 [==============================] - 0s 5ms/step
# >49, 33/39, d_loss_real=0.492, d_loss_fake=0.693, g_loss=1.003
# 2/2 [==============================] - 0s 5ms/step
# >49, 34/39, d_loss_real=0.546, d_loss_fake=0.653, g_loss=0.976
# 2/2 [==============================] - 0s 5ms/step
# >49, 35/39, d_loss_real=0.592, d_loss_fake=0.632, g_loss=1.071
# 2/2 [==============================] - 0s 9ms/step
# >49, 36/39, d_loss_real=0.530, d_loss_fake=0.563, g_loss=1.141
# 2/2 [==============================] - 0s 5ms/step
# >49, 37/39, d_loss_real=0.520, d_loss_fake=0.524, g_loss=1.257
# 2/2 [==============================] - 0s 5ms/step
# >49, 38/39, d_loss_real=0.592, d_loss_fake=0.478, g_loss=1.281
# 2/2 [==============================] - 0s 5ms/step
# >49, 39/39, d_loss_real=0.513, d_loss_fake=0.467, g_loss=1.291
# 2/2 [==============================] - 0s 4ms/step
# >50, 1/39, d_loss_real=0.584, d_loss_fake=0.461, g_loss=1.189
# 2/2 [==============================] - 0s 4ms/step
# >50, 2/39, d_loss_real=0.440, d_loss_fake=0.479, g_loss=1.235
# 2/2 [==============================] - 0s 7ms/step
# >50, 3/39, d_loss_real=0.488, d_loss_fake=0.497, g_loss=1.216
# 2/2 [==============================] - 0s 10ms/step
# >50, 4/39, d_loss_real=0.421, d_loss_fake=0.545, g_loss=1.250
# 2/2 [==============================] - 0s 5ms/step
# >50, 5/39, d_loss_real=0.391, d_loss_fake=0.558, g_loss=1.281
# 2/2 [==============================] - 0s 4ms/step
# >50, 6/39, d_loss_real=0.468, d_loss_fake=0.558, g_loss=1.313
# 2/2 [==============================] - 0s 5ms/step
# >50, 7/39, d_loss_real=0.601, d_loss_fake=0.525, g_loss=1.229
# 2/2 [==============================] - 0s 8ms/step
# >50, 8/39, d_loss_real=0.461, d_loss_fake=0.532, g_loss=1.233
# 2/2 [==============================] - 0s 5ms/step
# >50, 9/39, d_loss_real=0.429, d_loss_fake=0.605, g_loss=1.243
# 2/2 [==============================] - 0s 6ms/step
# >50, 10/39, d_loss_real=0.480, d_loss_fake=0.515, g_loss=1.305
# 2/2 [==============================] - 0s 5ms/step
# >50, 11/39, d_loss_real=0.527, d_loss_fake=0.557, g_loss=1.244
# 2/2 [==============================] - 0s 5ms/step
# >50, 12/39, d_loss_real=0.555, d_loss_fake=0.628, g_loss=1.075
# 2/2 [==============================] - 0s 4ms/step
# >50, 13/39, d_loss_real=0.545, d_loss_fake=0.634, g_loss=1.087
# 2/2 [==============================] - 0s 5ms/step
# >50, 14/39, d_loss_real=0.574, d_loss_fake=0.791, g_loss=1.039
# 2/2 [==============================] - 0s 4ms/step
# >50, 15/39, d_loss_real=0.516, d_loss_fake=0.831, g_loss=1.079
# 2/2 [==============================] - 0s 5ms/step
# >50, 16/39, d_loss_real=0.655, d_loss_fake=0.807, g_loss=1.086
# 2/2 [==============================] - 0s 4ms/step
# >50, 17/39, d_loss_real=0.582, d_loss_fake=0.562, g_loss=1.159
# 2/2 [==============================] - 0s 4ms/step
# >50, 18/39, d_loss_real=0.577, d_loss_fake=0.695, g_loss=1.116
# 2/2 [==============================] - 0s 4ms/step
# >50, 19/39, d_loss_real=0.518, d_loss_fake=0.693, g_loss=1.100
# 2/2 [==============================] - 0s 4ms/step
# >50, 20/39, d_loss_real=0.622, d_loss_fake=0.668, g_loss=1.231
# 2/2 [==============================] - 0s 4ms/step
# >50, 21/39, d_loss_real=0.563, d_loss_fake=0.548, g_loss=1.214
# 2/2 [==============================] - 0s 4ms/step
# >50, 22/39, d_loss_real=0.504, d_loss_fake=0.602, g_loss=1.266
# 2/2 [==============================] - 0s 6ms/step
# >50, 23/39, d_loss_real=0.541, d_loss_fake=0.611, g_loss=1.294
# 2/2 [==============================] - 0s 5ms/step
# >50, 24/39, d_loss_real=0.577, d_loss_fake=0.539, g_loss=1.295
# 2/2 [==============================] - 0s 6ms/step
# >50, 25/39, d_loss_real=0.579, d_loss_fake=0.662, g_loss=1.246
# 2/2 [==============================] - 0s 4ms/step
# >50, 26/39, d_loss_real=0.580, d_loss_fake=0.671, g_loss=1.248
# 2/2 [==============================] - 0s 4ms/step
# >50, 27/39, d_loss_real=0.738, d_loss_fake=0.647, g_loss=1.339
# 2/2 [==============================] - 0s 4ms/step
# >50, 28/39, d_loss_real=0.792, d_loss_fake=0.607, g_loss=1.258
# 2/2 [==============================] - 0s 4ms/step
# >50, 29/39, d_loss_real=0.750, d_loss_fake=0.580, g_loss=1.130
# 2/2 [==============================] - 0s 5ms/step
# >50, 30/39, d_loss_real=0.707, d_loss_fake=0.760, g_loss=1.130
# 2/2 [==============================] - 0s 4ms/step
# >50, 31/39, d_loss_real=0.726, d_loss_fake=0.711, g_loss=1.147
# 2/2 [==============================] - 0s 4ms/step
# >50, 32/39, d_loss_real=0.759, d_loss_fake=0.624, g_loss=1.185
# 2/2 [==============================] - 0s 4ms/step
# >50, 33/39, d_loss_real=0.669, d_loss_fake=0.633, g_loss=1.191
# 2/2 [==============================] - 0s 4ms/step
# >50, 34/39, d_loss_real=0.650, d_loss_fake=0.591, g_loss=1.109
# 2/2 [==============================] - 0s 6ms/step
# >50, 35/39, d_loss_real=0.645, d_loss_fake=0.497, g_loss=1.157
# 2/2 [==============================] - 0s 5ms/step
# >50, 36/39, d_loss_real=0.666, d_loss_fake=0.630, g_loss=1.110
# 2/2 [==============================] - 0s 4ms/step
# >50, 37/39, d_loss_real=0.739, d_loss_fake=0.582, g_loss=1.155
# 2/2 [==============================] - 0s 5ms/step
# >50, 38/39, d_loss_real=0.648, d_loss_fake=0.543, g_loss=1.142
# 2/2 [==============================] - 0s 4ms/step
# >50, 39/39, d_loss_real=0.623, d_loss_fake=0.595, g_loss=1.172
# 5/5 [==============================] - 0s 3ms/step
# >Accuracy real: 66%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def create_plot(examples, n):
    """
    Plot a grid of the generated images.

    Parameters:
    - examples: numpy array, the generated images to be plotted.
    - n: int, the dimension of the grid to display (e.g., n=3 for a 3x3 grid).
    """
    # Plot images in a grid of 'n x n'
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)

        # Turn off axis to focus on the images
        pyplot.axis('off')

        # Plot raw pixel data
        pyplot.imshow(examples[i, :, :])

    # Display the plot
    pyplot.show()

# %%
# Generate images
latent_points = generate_latent_points(100, 100)
X = g_model.predict(latent_points)
X = (X + 1)/ 2.0

# Plot a 10x10 grid of the generated images
create_plot(X, 10)
# Out:
# 4/4 [==============================] - 0s 79ms/step
