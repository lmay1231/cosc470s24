# %% [markdown]
# <a href="https://colab.research.google.com/github/lmay1231/cosc470s24/blob/main/Solutions/RegularGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import expand_dims
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot

# %%
def define_discriminator(input_shape=(32, 32, 3)):
    """
    Define the discriminator model structure for the DCGAN.

    Parameters:
    - input_shape: tuple, shape of the input images. Default is (32, 32, 3) for 32x32 RGB images.

    Returns:
    - Compiled Keras model of the discriminator.
    """
    model = Sequential()

    # Initial convolutional layer with input shape specification
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=input_shape))
    model.add(LeakyReLU(alpha=0.2))

    # First downsample: reduces image dimensions by half, increases depth
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Second downsample
    model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Third downsample
    model.add(Conv2D(256, (3, 3), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Flatten the output of the last convolutional layer
    model.add(Flatten())

    # Dropout for regularization (helps prevent overfitting)
    model.add(Dropout(0.4))

    # Output layer: binary classification (real or fake)
    model.add(Dense(1, activation='sigmoid'))

    # Compiling the model with Adam optimizer and binary crossentropy loss
    # Adjusted learning rate and beta_1 for stable training
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# %%
def define_generator(latent_dim):
    """
    Define the generator model structure for the DCGAN.

    Parameters:
    - latent_dim: int, size of the latent space (noise vector input).

    Returns:
    - Uncompiled Keras model of the generator.
    """
    model = Sequential()

    # Foundation for 4x4 image
    n_nodes = 256 * 4 * 4
    model.add(Dense(n_nodes, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Reshape((4, 4, 256)))

    # Upsample to 8x8
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 16x16
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Upsample to 32x32
    model.add(Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same'))
    model.add(LeakyReLU(alpha=0.2))

    # Output layer with tanh activation for generating images
    model.add(Conv2D(3, (3, 3), activation='tanh', padding='same'))

    return model

# %%
def define_gan(generator_model, discriminator_model):
    """
    Define the combined GAN model for training the generator.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN, set to non-trainable.

    Returns:
    - Compiled Keras model of the combined GAN, ready for training the generator.
    """
    # Set discriminator weights to non-trainable (only when part of the combined model)
    discriminator_model.trainable = False

    # Initialize the combined model
    model = Sequential()

    # Add generator
    model.add(generator_model)

    # Add discriminator
    model.add(discriminator_model)

    # Compile the combined model
    # The optimizer and loss function are set up for training the generator
    optimizer = Adam(learning_rate=0.0002, beta_1=0.5)
    model.compile(loss='binary_crossentropy', optimizer=optimizer)

    return model

# %%
def load_real_samples():
    """
    Load and prepare the CIFAR-10 training images.

    Returns:
    - X: numpy array, CIFAR-10 training images normalized to [-1, 1].
    """
    # Load CIFAR-10 dataset
    (trainX, _), (_, _) = load_data()

    # Convert image data from unsigned integers to floats
    X = trainX.astype('float32')

    # Normalize the images from [0,255] to [-1,1]
    X = (X - 127.5) / 127.5

    return X

# %%
def generate_real_samples(dataset, n_samples):
    """
    Select a random subset of real samples from a dataset.

    Parameters:
    - dataset: numpy array, the collection of images to select real samples from.
    - n_samples: int, the number of real samples to select.

    Returns:
    - X: numpy array, the selected images.
    - y: numpy array, an array of labels marking the selected images as real.
    """
    # Choose random instances
    ix = randint(0, dataset.shape[0], n_samples)

    # Retrieve selected images
    X = dataset[ix]

    # Generate 'real' class labels (1) for the selected samples
    y = ones((n_samples, 1))

    return X, y

# %%
def generate_latent_points(latent_dim, n_samples):
    """
    Generate points in the latent space as input for the generator.

    Parameters:
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate in the latent space.

    Returns:
    - x_input: numpy array, batch of latent points reshaped for the generator network.
    """
    # Generate points in the latent space
    x_input = randn(latent_dim * n_samples)

    # Reshape into a batch of inputs for the network
    x_input = x_input.reshape(n_samples, latent_dim)

    return x_input

# %%
def generate_fake_samples(generator_model, latent_dim, n_samples):
    """
    Use the generator to generate 'n' fake examples, along with their class labels.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of fake samples to generate.

    Returns:
    - X: numpy array, the generated fake images.
    - y: numpy array, an array of labels marking the images as fake.
    """
    # Generate points in latent space
    x_input = generate_latent_points(latent_dim, n_samples)

    # Use the generator model to predict (generate) outputs
    X = generator_model.predict(x_input)

    # Create 'fake' class labels (0) for the generated images
    y = zeros((n_samples, 1))

    return X, y

# %%
def save_plot(examples, epoch, n=7):
    """
    Create and save a plot of generated images.

    Parameters:
    - examples: numpy array, the generated images to plot.
    - epoch: int, the current epoch number, used to name the saved file.
    - n: int, the number of images to display along each dimension of the grid. Default is 7.
    """
    # Scale from [-1,1] to [0,1] for plotting
    examples = (examples + 1) / 2.0

    # Plot images
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)
        # Turn off axis
        pyplot.axis('off')
        # Plot raw pixel data
        pyplot.imshow(examples[i])

    # Save plot to file
    filename = f'generated_plot_e{epoch+1:03d}.png'
    pyplot.savefig(filename)
    pyplot.close()

# %%
def summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim, n_samples=150):
    """
    Evaluate the discriminator, plot generated images, and save the generator model.

    Parameters:
    - epoch: int, the current training epoch.
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_samples: int, the number of samples to generate for evaluation. Default is 150.
    """
    # Prepare real samples and evaluate discriminator on real examples
    X_real, y_real = generate_real_samples(dataset, n_samples)
    _, acc_real = discriminator_model.evaluate(X_real, y_real, verbose=0)

    # Prepare fake examples and evaluate discriminator on fake examples
    x_fake, y_fake = generate_fake_samples(generator_model, latent_dim, n_samples)
    _, acc_fake = discriminator_model.evaluate(x_fake, y_fake, verbose=0)

    # Summarize discriminator performance
    print(f'>Accuracy real: {acc_real*100:.0f}%, fake: {acc_fake*100:.0f}%')

    # Save plot of fake images
    save_plot(x_fake, epoch)

    # Save the generator model
    filename = f'generator_model_{epoch+1:03d}.h5'
    generator_model.save(filename)

# %%
def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, n_epochs=200, n_batch=128):
    """
    Train the generator and discriminator of the GAN.

    Parameters:
    - generator_model: Model, the generator component of the GAN.
    - discriminator_model: Model, the discriminator component of the GAN.
    - gan_model: Model, the combined GAN model for updating the generator.
    - dataset: numpy array, the dataset of real images.
    - latent_dim: int, the dimensionality of the latent space.
    - n_epochs: int, the number of epochs to train for. Default is 200.
    - n_batch: int, the size of the batch. Default is 128.
    """
    bat_per_epo = int(dataset.shape[0] / n_batch)
    half_batch = int(n_batch / 2)

    # Manually enumerate epochs
    for epoch in range(n_epochs):
        # Enumerate batches over the training set
        for batch in range(bat_per_epo):
            # Get randomly selected 'real' samples
            X_real, y_real = generate_real_samples(dataset, half_batch)
            # Update discriminator model weights
            d_loss_real = discriminator_model.train_on_batch(X_real, y_real)[0]

            # Generate 'fake' examples
            X_fake, y_fake = generate_fake_samples(generator_model, latent_dim, half_batch)
            # Update discriminator model weights
            d_loss_fake = discriminator_model.train_on_batch(X_fake, y_fake)[0]

            # Prepare points in latent space as input for the generator
            X_gan = generate_latent_points(latent_dim, n_batch)
            # Create inverted labels for the fake samples
            y_gan = ones((n_batch, 1))
            # Update the generator via the discriminator's error
            g_loss = gan_model.train_on_batch(X_gan, y_gan)

            # Summarize loss on this batch
            print(f'>{epoch+1}, {batch+1}/{bat_per_epo}, d_loss_real={d_loss_real:.3f}, d_loss_fake={d_loss_fake:.3f}, g_loss={g_loss:.3f}')

        # Evaluate the model performance, sometimes
        if (epoch + 1) % 10 == 0:
            summarize_performance(epoch, generator_model, discriminator_model, dataset, latent_dim)

# %%
latent_dim = 100

# Create models
d_model = define_discriminator()
g_model = define_generator(latent_dim)
gan_model = define_gan(g_model, d_model)

# Load CIFAR-10 dataset
dataset = load_real_samples()

# Train model(s)
train(g_model, d_model, gan_model, dataset, latent_dim, 10)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2/2 [==============================] - 0s 5ms/step
# >4, 232/390, d_loss_real=0.600, d_loss_fake=0.483, g_loss=1.237
# 2/2 [==============================] - 0s 5ms/step
# >4, 233/390, d_loss_real=0.574, d_loss_fake=0.523, g_loss=1.190
# 2/2 [==============================] - 0s 4ms/step
# >4, 234/390, d_loss_real=0.586, d_loss_fake=0.626, g_loss=1.094
# 2/2 [==============================] - 0s 4ms/step
# >4, 235/390, d_loss_real=0.454, d_loss_fake=0.591, g_loss=1.168
# 2/2 [==============================] - 0s 10ms/step
# >4, 236/390, d_loss_real=0.509, d_loss_fake=0.565, g_loss=1.014
# 2/2 [==============================] - 0s 4ms/step
# >4, 237/390, d_loss_real=0.697, d_loss_fake=0.680, g_loss=0.985
# 2/2 [==============================] - 0s 4ms/step
# >4, 238/390, d_loss_real=0.523, d_loss_fake=0.736, g_loss=0.892
# 2/2 [==============================] - 0s 4ms/step
# >4, 239/390, d_loss_real=0.638, d_loss_fake=0.757, g_loss=0.842
# 2/2 [==============================] - 0s 7ms/step
# >4, 240/390, d_loss_real=0.610, d_loss_fake=0.827, g_loss=0.826
# 2/2 [==============================] - 0s 9ms/step
# >4, 241/390, d_loss_real=0.605, d_loss_fake=0.800, g_loss=0.844
# 2/2 [==============================] - 0s 6ms/step
# >4, 242/390, d_loss_real=0.536, d_loss_fake=0.643, g_loss=0.949
# 2/2 [==============================] - 0s 9ms/step
# >4, 243/390, d_loss_real=0.516, d_loss_fake=0.585, g_loss=1.050
# 2/2 [==============================] - 0s 6ms/step
# >4, 244/390, d_loss_real=0.437, d_loss_fake=0.489, g_loss=1.216
# 2/2 [==============================] - 0s 5ms/step
# >4, 245/390, d_loss_real=0.482, d_loss_fake=0.477, g_loss=1.147
# 2/2 [==============================] - 0s 4ms/step
# >4, 246/390, d_loss_real=0.321, d_loss_fake=0.435, g_loss=1.357
# 2/2 [==============================] - 0s 5ms/step
# >4, 247/390, d_loss_real=0.340, d_loss_fake=0.438, g_loss=1.292
# 2/2 [==============================] - 0s 5ms/step
# >4, 248/390, d_loss_real=0.321, d_loss_fake=0.537, g_loss=1.236
# 2/2 [==============================] - 0s 4ms/step
# >4, 249/390, d_loss_real=0.372, d_loss_fake=0.545, g_loss=1.056
# 2/2 [==============================] - 0s 4ms/step
# >4, 250/390, d_loss_real=0.335, d_loss_fake=0.703, g_loss=1.064
# 2/2 [==============================] - 0s 4ms/step
# >4, 251/390, d_loss_real=0.314, d_loss_fake=0.779, g_loss=0.998
# 2/2 [==============================] - 0s 4ms/step
# >4, 252/390, d_loss_real=0.373, d_loss_fake=0.814, g_loss=1.125
# 2/2 [==============================] - 0s 4ms/step
# >4, 253/390, d_loss_real=0.569, d_loss_fake=0.571, g_loss=1.194
# 2/2 [==============================] - 0s 4ms/step
# >4, 254/390, d_loss_real=0.462, d_loss_fake=0.549, g_loss=1.275
# 2/2 [==============================] - 0s 4ms/step
# >4, 255/390, d_loss_real=0.371, d_loss_fake=0.522, g_loss=1.475
# 2/2 [==============================] - 0s 4ms/step
# >4, 256/390, d_loss_real=0.437, d_loss_fake=0.467, g_loss=1.600
# 2/2 [==============================] - 0s 4ms/step
# >4, 257/390, d_loss_real=0.492, d_loss_fake=0.407, g_loss=1.857
# 2/2 [==============================] - 0s 5ms/step
# >4, 258/390, d_loss_real=0.461, d_loss_fake=0.315, g_loss=1.883
# 2/2 [==============================] - 0s 5ms/step
# >4, 259/390, d_loss_real=0.528, d_loss_fake=0.401, g_loss=2.347
# 2/2 [==============================] - 0s 4ms/step
# >4, 260/390, d_loss_real=0.673, d_loss_fake=0.321, g_loss=1.836
# 2/2 [==============================] - 0s 4ms/step
# >4, 261/390, d_loss_real=0.536, d_loss_fake=0.597, g_loss=1.476
# 2/2 [==============================] - 0s 4ms/step
# >4, 262/390, d_loss_real=0.410, d_loss_fake=0.975, g_loss=1.734
# 2/2 [==============================] - 0s 4ms/step
# >4, 263/390, d_loss_real=0.684, d_loss_fake=0.627, g_loss=1.473
# 2/2 [==============================] - 0s 4ms/step
# >4, 264/390, d_loss_real=0.790, d_loss_fake=0.619, g_loss=1.359
# 2/2 [==============================] - 0s 6ms/step
# >4, 265/390, d_loss_real=0.886, d_loss_fake=0.777, g_loss=1.376
# 2/2 [==============================] - 0s 3ms/step
# >4, 266/390, d_loss_real=0.905, d_loss_fake=0.621, g_loss=1.304
# 2/2 [==============================] - 0s 4ms/step
# >4, 267/390, d_loss_real=0.954, d_loss_fake=0.526, g_loss=1.270
# 2/2 [==============================] - 0s 4ms/step
# >4, 268/390, d_loss_real=0.874, d_loss_fake=0.509, g_loss=1.198
# 2/2 [==============================] - 0s 4ms/step
# >4, 269/390, d_loss_real=0.808, d_loss_fake=0.601, g_loss=1.154
# 2/2 [==============================] - 0s 3ms/step
# >4, 270/390, d_loss_real=0.748, d_loss_fake=0.582, g_loss=1.172
# 2/2 [==============================] - 0s 4ms/step
# >4, 271/390, d_loss_real=0.678, d_loss_fake=0.531, g_loss=1.150
# 2/2 [==============================] - 0s 4ms/step
# >4, 272/390, d_loss_real=0.651, d_loss_fake=0.552, g_loss=1.159
# 2/2 [==============================] - 0s 3ms/step
# >4, 273/390, d_loss_real=0.589, d_loss_fake=0.522, g_loss=1.123
# 2/2 [==============================] - 0s 5ms/step
# >4, 274/390, d_loss_real=0.498, d_loss_fake=0.522, g_loss=1.143
# 2/2 [==============================] - 0s 4ms/step
# >4, 275/390, d_loss_real=0.538, d_loss_fake=0.534, g_loss=1.162
# 2/2 [==============================] - 0s 4ms/step
# >4, 276/390, d_loss_real=0.493, d_loss_fake=0.545, g_loss=1.189
# 2/2 [==============================] - 0s 4ms/step
# >4, 277/390, d_loss_real=0.527, d_loss_fake=0.602, g_loss=1.157
# 2/2 [==============================] - 0s 3ms/step
# >4, 278/390, d_loss_real=0.543, d_loss_fake=0.520, g_loss=1.229
# 2/2 [==============================] - 0s 5ms/step
# >4, 279/390, d_loss_real=0.639, d_loss_fake=0.518, g_loss=1.234
# 2/2 [==============================] - 0s 3ms/step
# >4, 280/390, d_loss_real=0.555, d_loss_fake=0.552, g_loss=1.220
# 2/2 [==============================] - 0s 4ms/step
# >4, 281/390, d_loss_real=0.675, d_loss_fake=0.551, g_loss=1.316
# 2/2 [==============================] - 0s 4ms/step
# >4, 282/390, d_loss_real=0.678, d_loss_fake=0.451, g_loss=1.237
# 2/2 [==============================] - 0s 4ms/step
# >4, 283/390, d_loss_real=0.544, d_loss_fake=0.529, g_loss=1.179
# 2/2 [==============================] - 0s 5ms/step
# >4, 284/390, d_loss_real=0.652, d_loss_fake=0.486, g_loss=1.236
# 2/2 [==============================] - 0s 4ms/step
# >4, 285/390, d_loss_real=0.702, d_loss_fake=0.532, g_loss=1.171
# 2/2 [==============================] - 0s 5ms/step
# >4, 286/390, d_loss_real=0.549, d_loss_fake=0.522, g_loss=1.221
# 2/2 [==============================] - 0s 4ms/step
# >4, 287/390, d_loss_real=0.758, d_loss_fake=0.521, g_loss=1.235
# 2/2 [==============================] - 0s 3ms/step
# >4, 288/390, d_loss_real=0.735, d_loss_fake=0.535, g_loss=1.226
# 2/2 [==============================] - 0s 11ms/step
# >4, 289/390, d_loss_real=0.737, d_loss_fake=0.488, g_loss=1.346
# 2/2 [==============================] - 0s 3ms/step
# >4, 290/390, d_loss_real=0.779, d_loss_fake=0.480, g_loss=1.280
# 2/2 [==============================] - 0s 4ms/step
# >4, 291/390, d_loss_real=0.694, d_loss_fake=0.503, g_loss=1.243
# 2/2 [==============================] - 0s 4ms/step
# >4, 292/390, d_loss_real=0.673, d_loss_fake=0.467, g_loss=1.256
# 2/2 [==============================] - 0s 5ms/step
# >4, 293/390, d_loss_real=0.710, d_loss_fake=0.482, g_loss=1.229
# 2/2 [==============================] - 0s 4ms/step
# >4, 294/390, d_loss_real=0.629, d_loss_fake=0.491, g_loss=1.163
# 2/2 [==============================] - 0s 5ms/step
# >4, 295/390, d_loss_real=0.650, d_loss_fake=0.595, g_loss=1.150
# 2/2 [==============================] - 0s 5ms/step
# >4, 296/390, d_loss_real=0.622, d_loss_fake=0.536, g_loss=1.167
# 2/2 [==============================] - 0s 5ms/step
# >4, 297/390, d_loss_real=0.595, d_loss_fake=0.558, g_loss=1.177
# 2/2 [==============================] - 0s 4ms/step
# >4, 298/390, d_loss_real=0.596, d_loss_fake=0.546, g_loss=1.126
# 2/2 [==============================] - 0s 5ms/step
# >4, 299/390, d_loss_real=0.625, d_loss_fake=0.572, g_loss=1.150
# 2/2 [==============================] - 0s 4ms/step
# >4, 300/390, d_loss_real=0.602, d_loss_fake=0.559, g_loss=1.190
# 2/2 [==============================] - 0s 4ms/step
# >4, 301/390, d_loss_real=0.536, d_loss_fake=0.540, g_loss=1.146
# 2/2 [==============================] - 0s 4ms/step
# >4, 302/390, d_loss_real=0.601, d_loss_fake=0.565, g_loss=1.001
# 2/2 [==============================] - 0s 5ms/step
# >4, 303/390, d_loss_real=0.543, d_loss_fake=0.708, g_loss=0.970
# 2/2 [==============================] - 0s 3ms/step
# >4, 304/390, d_loss_real=0.599, d_loss_fake=0.790, g_loss=0.908
# 2/2 [==============================] - 0s 5ms/step
# >4, 305/390, d_loss_real=0.552, d_loss_fake=0.815, g_loss=0.828
# 2/2 [==============================] - 0s 5ms/step
# >4, 306/390, d_loss_real=0.578, d_loss_fake=0.766, g_loss=0.820
# 2/2 [==============================] - 0s 5ms/step
# >4, 307/390, d_loss_real=0.675, d_loss_fake=0.864, g_loss=0.807
# 2/2 [==============================] - 0s 4ms/step
# >4, 308/390, d_loss_real=0.563, d_loss_fake=0.795, g_loss=0.857
# 2/2 [==============================] - 0s 6ms/step
# >4, 309/390, d_loss_real=0.667, d_loss_fake=0.710, g_loss=0.865
# 2/2 [==============================] - 0s 4ms/step
# >4, 310/390, d_loss_real=0.657, d_loss_fake=0.736, g_loss=0.912
# 2/2 [==============================] - 0s 4ms/step
# >4, 311/390, d_loss_real=0.535, d_loss_fake=0.684, g_loss=0.961
# 2/2 [==============================] - 0s 9ms/step
# >4, 312/390, d_loss_real=0.526, d_loss_fake=0.625, g_loss=1.001
# 2/2 [==============================] - 0s 4ms/step
# >4, 313/390, d_loss_real=0.607, d_loss_fake=0.615, g_loss=1.027
# 2/2 [==============================] - 0s 4ms/step
# >4, 314/390, d_loss_real=0.473, d_loss_fake=0.540, g_loss=1.106
# 2/2 [==============================] - 0s 4ms/step
# >4, 315/390, d_loss_real=0.473, d_loss_fake=0.504, g_loss=1.111
# 2/2 [==============================] - 0s 6ms/step
# >4, 316/390, d_loss_real=0.428, d_loss_fake=0.490, g_loss=1.143
# 2/2 [==============================] - 0s 4ms/step
# >4, 317/390, d_loss_real=0.396, d_loss_fake=0.472, g_loss=1.177
# 2/2 [==============================] - 0s 4ms/step
# >4, 318/390, d_loss_real=0.381, d_loss_fake=0.420, g_loss=1.303
# 2/2 [==============================] - 0s 4ms/step
# >4, 319/390, d_loss_real=0.345, d_loss_fake=0.452, g_loss=1.301
# 2/2 [==============================] - 0s 4ms/step
# >4, 320/390, d_loss_real=0.377, d_loss_fake=0.490, g_loss=1.229
# 2/2 [==============================] - 0s 4ms/step
# >4, 321/390, d_loss_real=0.395, d_loss_fake=0.640, g_loss=1.090
# 2/2 [==============================] - 0s 4ms/step
# >4, 322/390, d_loss_real=0.529, d_loss_fake=0.883, g_loss=1.075
# 2/2 [==============================] - 0s 5ms/step
# >4, 323/390, d_loss_real=0.620, d_loss_fake=0.810, g_loss=1.055
# 2/2 [==============================] - 0s 6ms/step
# >4, 324/390, d_loss_real=0.864, d_loss_fake=0.766, g_loss=1.146
# 2/2 [==============================] - 0s 5ms/step
# >4, 325/390, d_loss_real=0.812, d_loss_fake=0.701, g_loss=1.271
# 2/2 [==============================] - 0s 5ms/step
# >4, 326/390, d_loss_real=0.989, d_loss_fake=0.607, g_loss=1.258
# 2/2 [==============================] - 0s 4ms/step
# >4, 327/390, d_loss_real=1.041, d_loss_fake=0.555, g_loss=1.325
# 2/2 [==============================] - 0s 4ms/step
# >4, 328/390, d_loss_real=0.892, d_loss_fake=0.511, g_loss=1.396
# 2/2 [==============================] - 0s 4ms/step
# >4, 329/390, d_loss_real=0.884, d_loss_fake=0.460, g_loss=1.398
# 2/2 [==============================] - 0s 5ms/step
# >4, 330/390, d_loss_real=0.715, d_loss_fake=0.391, g_loss=1.568
# 2/2 [==============================] - 0s 5ms/step
# >4, 331/390, d_loss_real=0.671, d_loss_fake=0.314, g_loss=1.715
# 2/2 [==============================] - 0s 4ms/step
# >4, 332/390, d_loss_real=0.682, d_loss_fake=0.318, g_loss=1.696
# 2/2 [==============================] - 0s 7ms/step
# >4, 333/390, d_loss_real=0.598, d_loss_fake=0.368, g_loss=1.635
# 2/2 [==============================] - 0s 5ms/step
# >4, 334/390, d_loss_real=0.583, d_loss_fake=0.337, g_loss=1.537
# 2/2 [==============================] - 0s 4ms/step
# >4, 335/390, d_loss_real=0.531, d_loss_fake=0.460, g_loss=1.391
# 2/2 [==============================] - 0s 4ms/step
# >4, 336/390, d_loss_real=0.669, d_loss_fake=0.522, g_loss=1.281
# 2/2 [==============================] - 0s 5ms/step
# >4, 337/390, d_loss_real=0.687, d_loss_fake=0.555, g_loss=1.319
# 2/2 [==============================] - 0s 5ms/step
# >4, 338/390, d_loss_real=0.708, d_loss_fake=0.596, g_loss=1.321
# 2/2 [==============================] - 0s 5ms/step
# >4, 339/390, d_loss_real=0.793, d_loss_fake=0.527, g_loss=1.264
# 2/2 [==============================] - 0s 5ms/step
# >4, 340/390, d_loss_real=0.741, d_loss_fake=0.580, g_loss=1.247
# 2/2 [==============================] - 0s 4ms/step
# >4, 341/390, d_loss_real=0.624, d_loss_fake=0.492, g_loss=1.331
# 2/2 [==============================] - 0s 4ms/step
# >4, 342/390, d_loss_real=0.758, d_loss_fake=0.527, g_loss=1.271
# 2/2 [==============================] - 0s 5ms/step
# >4, 343/390, d_loss_real=0.709, d_loss_fake=0.542, g_loss=1.264
# 2/2 [==============================] - 0s 4ms/step
# >4, 344/390, d_loss_real=0.581, d_loss_fake=0.468, g_loss=1.243
# 2/2 [==============================] - 0s 6ms/step
# >4, 345/390, d_loss_real=0.957, d_loss_fake=0.596, g_loss=1.112
# 2/2 [==============================] - 0s 5ms/step
# >4, 346/390, d_loss_real=0.571, d_loss_fake=0.609, g_loss=1.087
# 2/2 [==============================] - 0s 9ms/step
# >4, 347/390, d_loss_real=0.709, d_loss_fake=0.589, g_loss=1.070
# 2/2 [==============================] - 0s 4ms/step
# >4, 348/390, d_loss_real=0.666, d_loss_fake=0.575, g_loss=1.078
# 2/2 [==============================] - 0s 4ms/step
# >4, 349/390, d_loss_real=0.681, d_loss_fake=0.634, g_loss=1.033
# 2/2 [==============================] - 0s 6ms/step
# >4, 350/390, d_loss_real=0.751, d_loss_fake=0.594, g_loss=1.048
# 2/2 [==============================] - 0s 4ms/step
# >4, 351/390, d_loss_real=0.664, d_loss_fake=0.561, g_loss=1.019
# 2/2 [==============================] - 0s 5ms/step
# >4, 352/390, d_loss_real=0.723, d_loss_fake=0.649, g_loss=1.036
# 2/2 [==============================] - 0s 5ms/step
# >4, 353/390, d_loss_real=0.669, d_loss_fake=0.620, g_loss=1.071
# 2/2 [==============================] - 0s 3ms/step
# >4, 354/390, d_loss_real=0.595, d_loss_fake=0.565, g_loss=1.053
# 2/2 [==============================] - 0s 5ms/step
# >4, 355/390, d_loss_real=0.593, d_loss_fake=0.576, g_loss=1.083
# 2/2 [==============================] - 0s 4ms/step
# >4, 356/390, d_loss_real=0.536, d_loss_fake=0.555, g_loss=0.988
# 2/2 [==============================] - 0s 5ms/step
# >4, 357/390, d_loss_real=0.638, d_loss_fake=0.588, g_loss=0.977
# 2/2 [==============================] - 0s 4ms/step
# >4, 358/390, d_loss_real=0.514, d_loss_fake=0.579, g_loss=1.020
# 2/2 [==============================] - 0s 3ms/step
# >4, 359/390, d_loss_real=0.480, d_loss_fake=0.607, g_loss=0.984
# 2/2 [==============================] - 0s 4ms/step
# >4, 360/390, d_loss_real=0.428, d_loss_fake=0.588, g_loss=0.986
# 2/2 [==============================] - 0s 5ms/step
# >4, 361/390, d_loss_real=0.442, d_loss_fake=0.562, g_loss=0.942
# 2/2 [==============================] - 0s 4ms/step
# >4, 362/390, d_loss_real=0.393, d_loss_fake=0.590, g_loss=0.986
# 2/2 [==============================] - 0s 4ms/step
# >4, 363/390, d_loss_real=0.450, d_loss_fake=0.567, g_loss=0.977
# 2/2 [==============================] - 0s 4ms/step
# >4, 364/390, d_loss_real=0.401, d_loss_fake=0.569, g_loss=0.937
# 2/2 [==============================] - 0s 4ms/step
# >4, 365/390, d_loss_real=0.396, d_loss_fake=0.623, g_loss=0.935
# 2/2 [==============================] - 0s 4ms/step
# >4, 366/390, d_loss_real=0.375, d_loss_fake=0.641, g_loss=0.903
# 2/2 [==============================] - 0s 4ms/step
# >4, 367/390, d_loss_real=0.416, d_loss_fake=0.587, g_loss=0.885
# 2/2 [==============================] - 0s 4ms/step
# >4, 368/390, d_loss_real=0.428, d_loss_fake=0.681, g_loss=0.876
# 2/2 [==============================] - 0s 4ms/step
# >4, 369/390, d_loss_real=0.421, d_loss_fake=0.739, g_loss=0.995
# 2/2 [==============================] - 0s 5ms/step
# >4, 370/390, d_loss_real=0.472, d_loss_fake=0.686, g_loss=0.982
# 2/2 [==============================] - 0s 4ms/step
# >4, 371/390, d_loss_real=0.518, d_loss_fake=0.653, g_loss=0.986
# 2/2 [==============================] - 0s 5ms/step
# >4, 372/390, d_loss_real=0.544, d_loss_fake=0.674, g_loss=0.966
# 2/2 [==============================] - 0s 5ms/step
# >4, 373/390, d_loss_real=0.508, d_loss_fake=0.683, g_loss=1.004
# 2/2 [==============================] - 0s 5ms/step
# >4, 374/390, d_loss_real=0.524, d_loss_fake=0.595, g_loss=0.998
# 2/2 [==============================] - 0s 4ms/step
# >4, 375/390, d_loss_real=0.568, d_loss_fake=0.657, g_loss=1.008
# 2/2 [==============================] - 0s 3ms/step
# >4, 376/390, d_loss_real=0.642, d_loss_fake=0.609, g_loss=1.067
# 2/2 [==============================] - 0s 4ms/step
# >4, 377/390, d_loss_real=0.574, d_loss_fake=0.572, g_loss=1.013
# 2/2 [==============================] - 0s 4ms/step
# >4, 378/390, d_loss_real=0.590, d_loss_fake=0.596, g_loss=1.069
# 2/2 [==============================] - 0s 5ms/step
# >4, 379/390, d_loss_real=0.523, d_loss_fake=0.535, g_loss=1.085
# 2/2 [==============================] - 0s 4ms/step
# >4, 380/390, d_loss_real=0.520, d_loss_fake=0.577, g_loss=1.094
# 2/2 [==============================] - 0s 4ms/step
# >4, 381/390, d_loss_real=0.603, d_loss_fake=0.520, g_loss=1.119
# 2/2 [==============================] - 0s 4ms/step
# >4, 382/390, d_loss_real=0.521, d_loss_fake=0.486, g_loss=1.142
# 2/2 [==============================] - 0s 4ms/step
# >4, 383/390, d_loss_real=0.455, d_loss_fake=0.571, g_loss=1.248
# 2/2 [==============================] - 0s 4ms/step
# >4, 384/390, d_loss_real=0.494, d_loss_fake=0.466, g_loss=1.322
# 2/2 [==============================] - 0s 5ms/step
# >4, 385/390, d_loss_real=0.552, d_loss_fake=0.448, g_loss=1.254
# 2/2 [==============================] - 0s 4ms/step
# >4, 386/390, d_loss_real=0.500, d_loss_fake=0.527, g_loss=1.220
# 2/2 [==============================] - 0s 5ms/step
# >4, 387/390, d_loss_real=0.449, d_loss_fake=0.514, g_loss=1.193
# 2/2 [==============================] - 0s 9ms/step
# >4, 388/390, d_loss_real=0.464, d_loss_fake=0.554, g_loss=1.204
# 2/2 [==============================] - 0s 4ms/step
# >4, 389/390, d_loss_real=0.480, d_loss_fake=0.648, g_loss=1.198
# 2/2 [==============================] - 0s 5ms/step
# >4, 390/390, d_loss_real=0.622, d_loss_fake=0.703, g_loss=1.170
# 2/2 [==============================] - 0s 4ms/step
# >5, 1/390, d_loss_real=0.536, d_loss_fake=0.725, g_loss=1.206
# 2/2 [==============================] - 0s 4ms/step
# >5, 2/390, d_loss_real=0.705, d_loss_fake=0.688, g_loss=1.256
# 2/2 [==============================] - 0s 5ms/step
# >5, 3/390, d_loss_real=0.696, d_loss_fake=0.701, g_loss=1.334
# 2/2 [==============================] - 0s 5ms/step
# >5, 4/390, d_loss_real=0.735, d_loss_fake=0.564, g_loss=1.365
# 2/2 [==============================] - 0s 5ms/step
# >5, 5/390, d_loss_real=0.660, d_loss_fake=0.535, g_loss=1.411
# 2/2 [==============================] - 0s 5ms/step
# >5, 6/390, d_loss_real=0.609, d_loss_fake=0.469, g_loss=1.504
# 2/2 [==============================] - 0s 5ms/step
# >5, 7/390, d_loss_real=0.564, d_loss_fake=0.436, g_loss=1.511
# 2/2 [==============================] - 0s 6ms/step
# >5, 8/390, d_loss_real=0.545, d_loss_fake=0.372, g_loss=1.678
# 2/2 [==============================] - 0s 5ms/step
# >5, 9/390, d_loss_real=0.478, d_loss_fake=0.313, g_loss=1.647
# 2/2 [==============================] - 0s 4ms/step
# >5, 10/390, d_loss_real=0.527, d_loss_fake=0.283, g_loss=1.609
# 2/2 [==============================] - 0s 4ms/step
# >5, 11/390, d_loss_real=0.377, d_loss_fake=0.356, g_loss=1.598
# 2/2 [==============================] - 0s 4ms/step
# >5, 12/390, d_loss_real=0.521, d_loss_fake=0.357, g_loss=1.455
# 2/2 [==============================] - 0s 4ms/step
# >5, 13/390, d_loss_real=0.434, d_loss_fake=0.426, g_loss=1.506
# 2/2 [==============================] - 0s 4ms/step
# >5, 14/390, d_loss_real=0.543, d_loss_fake=0.540, g_loss=1.402
# 2/2 [==============================] - 0s 5ms/step
# >5, 15/390, d_loss_real=0.525, d_loss_fake=0.464, g_loss=1.391
# 2/2 [==============================] - 0s 5ms/step
# >5, 16/390, d_loss_real=0.584, d_loss_fake=0.668, g_loss=1.434
# 2/2 [==============================] - 0s 4ms/step
# >5, 17/390, d_loss_real=0.617, d_loss_fake=0.570, g_loss=1.427
# 2/2 [==============================] - 0s 6ms/step
# >5, 18/390, d_loss_real=0.650, d_loss_fake=0.691, g_loss=1.445
# 2/2 [==============================] - 0s 4ms/step
# >5, 19/390, d_loss_real=0.570, d_loss_fake=0.704, g_loss=1.467
# 2/2 [==============================] - 0s 4ms/step
# >5, 20/390, d_loss_real=0.683, d_loss_fake=0.751, g_loss=1.440
# 2/2 [==============================] - 0s 4ms/step
# >5, 21/390, d_loss_real=0.777, d_loss_fake=0.660, g_loss=1.533
# 2/2 [==============================] - 0s 4ms/step
# >5, 22/390, d_loss_real=0.894, d_loss_fake=0.566, g_loss=1.395
# 2/2 [==============================] - 0s 4ms/step
# >5, 23/390, d_loss_real=0.918, d_loss_fake=0.445, g_loss=1.329
# 2/2 [==============================] - 0s 3ms/step
# >5, 24/390, d_loss_real=0.799, d_loss_fake=0.491, g_loss=1.283
# 2/2 [==============================] - 0s 5ms/step
# >5, 25/390, d_loss_real=0.779, d_loss_fake=0.466, g_loss=1.385
# 2/2 [==============================] - 0s 11ms/step
# >5, 26/390, d_loss_real=0.727, d_loss_fake=0.474, g_loss=1.402
# 2/2 [==============================] - 0s 4ms/step
# >5, 27/390, d_loss_real=0.619, d_loss_fake=0.404, g_loss=1.562
# 2/2 [==============================] - 0s 5ms/step
# >5, 28/390, d_loss_real=0.703, d_loss_fake=0.388, g_loss=1.413
# 2/2 [==============================] - 0s 4ms/step
# >5, 29/390, d_loss_real=0.630, d_loss_fake=0.375, g_loss=1.350
# 2/2 [==============================] - 0s 4ms/step
# >5, 30/390, d_loss_real=0.561, d_loss_fake=0.447, g_loss=1.408
# 2/2 [==============================] - 0s 4ms/step
# >5, 31/390, d_loss_real=0.511, d_loss_fake=0.408, g_loss=1.442
# 2/2 [==============================] - 0s 4ms/step
# >5, 32/390, d_loss_real=0.515, d_loss_fake=0.395, g_loss=1.403
# 2/2 [==============================] - 0s 5ms/step
# >5, 33/390, d_loss_real=0.522, d_loss_fake=0.452, g_loss=1.342
# 2/2 [==============================] - 0s 4ms/step
# >5, 34/390, d_loss_real=0.483, d_loss_fake=0.420, g_loss=1.264
# 2/2 [==============================] - 0s 4ms/step
# >5, 35/390, d_loss_real=0.536, d_loss_fake=0.494, g_loss=1.260
# 2/2 [==============================] - 0s 4ms/step
# >5, 36/390, d_loss_real=0.456, d_loss_fake=0.515, g_loss=1.226
# 2/2 [==============================] - 0s 5ms/step
# >5, 37/390, d_loss_real=0.426, d_loss_fake=0.519, g_loss=1.197
# 2/2 [==============================] - 0s 3ms/step
# >5, 38/390, d_loss_real=0.523, d_loss_fake=0.631, g_loss=1.264
# 2/2 [==============================] - 0s 4ms/step
# >5, 39/390, d_loss_real=0.496, d_loss_fake=0.706, g_loss=1.153
# 2/2 [==============================] - 0s 4ms/step
# >5, 40/390, d_loss_real=0.751, d_loss_fake=0.722, g_loss=1.050
# 2/2 [==============================] - 0s 6ms/step
# >5, 41/390, d_loss_real=0.690, d_loss_fake=0.821, g_loss=0.957
# 2/2 [==============================] - 0s 3ms/step
# >5, 42/390, d_loss_real=0.625, d_loss_fake=0.901, g_loss=0.979
# 2/2 [==============================] - 0s 3ms/step
# >5, 43/390, d_loss_real=0.768, d_loss_fake=0.834, g_loss=0.892
# 2/2 [==============================] - 0s 4ms/step
# >5, 44/390, d_loss_real=0.578, d_loss_fake=0.720, g_loss=0.993
# 2/2 [==============================] - 0s 5ms/step
# >5, 45/390, d_loss_real=0.555, d_loss_fake=0.751, g_loss=1.026
# 2/2 [==============================] - 0s 10ms/step
# >5, 46/390, d_loss_real=0.504, d_loss_fake=0.568, g_loss=1.041
# 2/2 [==============================] - 0s 6ms/step
# >5, 47/390, d_loss_real=0.435, d_loss_fake=0.608, g_loss=1.188
# 2/2 [==============================] - 0s 5ms/step
# >5, 48/390, d_loss_real=0.438, d_loss_fake=0.562, g_loss=1.242
# 2/2 [==============================] - 0s 4ms/step
# >5, 49/390, d_loss_real=0.537, d_loss_fake=0.558, g_loss=1.380
# 2/2 [==============================] - 0s 4ms/step
# >5, 50/390, d_loss_real=0.338, d_loss_fake=0.584, g_loss=1.264
# 2/2 [==============================] - 0s 5ms/step
# >5, 51/390, d_loss_real=0.591, d_loss_fake=0.603, g_loss=1.189
# 2/2 [==============================] - 0s 4ms/step
# >5, 52/390, d_loss_real=0.546, d_loss_fake=0.556, g_loss=1.218
# 2/2 [==============================] - 0s 5ms/step
# >5, 53/390, d_loss_real=0.465, d_loss_fake=0.515, g_loss=1.316
# 2/2 [==============================] - 0s 4ms/step
# >5, 54/390, d_loss_real=0.579, d_loss_fake=0.607, g_loss=1.243
# 2/2 [==============================] - 0s 4ms/step
# >5, 55/390, d_loss_real=0.464, d_loss_fake=0.649, g_loss=1.201
# 2/2 [==============================] - 0s 4ms/step
# >5, 56/390, d_loss_real=0.491, d_loss_fake=0.573, g_loss=1.298
# 2/2 [==============================] - 0s 5ms/step
# >5, 57/390, d_loss_real=0.562, d_loss_fake=0.428, g_loss=1.335
# 2/2 [==============================] - 0s 4ms/step
# >5, 58/390, d_loss_real=0.612, d_loss_fake=0.537, g_loss=1.237
# 2/2 [==============================] - 0s 5ms/step
# >5, 59/390, d_loss_real=0.583, d_loss_fake=0.541, g_loss=1.268
# 2/2 [==============================] - 0s 4ms/step
# >5, 60/390, d_loss_real=0.553, d_loss_fake=0.511, g_loss=1.270
# 2/2 [==============================] - 0s 4ms/step
# >5, 61/390, d_loss_real=0.676, d_loss_fake=0.516, g_loss=1.362
# 2/2 [==============================] - 0s 4ms/step
# >5, 62/390, d_loss_real=0.672, d_loss_fake=0.522, g_loss=1.422
# 2/2 [==============================] - 0s 4ms/step
# >5, 63/390, d_loss_real=0.610, d_loss_fake=0.413, g_loss=1.449
# 2/2 [==============================] - 0s 4ms/step
# >5, 64/390, d_loss_real=0.474, d_loss_fake=0.406, g_loss=1.503
# 2/2 [==============================] - 0s 4ms/step
# >5, 65/390, d_loss_real=0.548, d_loss_fake=0.434, g_loss=1.459
# 2/2 [==============================] - 0s 4ms/step
# >5, 66/390, d_loss_real=0.513, d_loss_fake=0.480, g_loss=1.407
# 2/2 [==============================] - 0s 6ms/step
# >5, 67/390, d_loss_real=0.579, d_loss_fake=0.560, g_loss=1.289
# 2/2 [==============================] - 0s 7ms/step
# >5, 68/390, d_loss_real=0.503, d_loss_fake=0.584, g_loss=1.255
# 2/2 [==============================] - 0s 4ms/step
# >5, 69/390, d_loss_real=0.570, d_loss_fake=0.579, g_loss=1.324
# 2/2 [==============================] - 0s 4ms/step
# >5, 70/390, d_loss_real=0.540, d_loss_fake=0.533, g_loss=1.338
# 2/2 [==============================] - 0s 4ms/step
# >5, 71/390, d_loss_real=0.514, d_loss_fake=0.450, g_loss=1.369
# 2/2 [==============================] - 0s 4ms/step
# >5, 72/390, d_loss_real=0.440, d_loss_fake=0.496, g_loss=1.409
# 2/2 [==============================] - 0s 6ms/step
# >5, 73/390, d_loss_real=0.618, d_loss_fake=0.519, g_loss=1.302
# 2/2 [==============================] - 0s 4ms/step
# >5, 74/390, d_loss_real=0.475, d_loss_fake=0.530, g_loss=1.251
# 2/2 [==============================] - 0s 10ms/step
# >5, 75/390, d_loss_real=0.485, d_loss_fake=0.549, g_loss=1.235
# 2/2 [==============================] - 0s 5ms/step
# >5, 76/390, d_loss_real=0.451, d_loss_fake=0.493, g_loss=1.246
# 2/2 [==============================] - 0s 4ms/step
# >5, 77/390, d_loss_real=0.392, d_loss_fake=0.602, g_loss=1.193
# 2/2 [==============================] - 0s 4ms/step
# >5, 78/390, d_loss_real=0.584, d_loss_fake=0.635, g_loss=1.151
# 2/2 [==============================] - 0s 4ms/step
# >5, 79/390, d_loss_real=0.484, d_loss_fake=0.689, g_loss=1.162
# 2/2 [==============================] - 0s 4ms/step
# >5, 80/390, d_loss_real=0.483, d_loss_fake=0.636, g_loss=1.167
# 2/2 [==============================] - 0s 6ms/step
# >5, 81/390, d_loss_real=0.538, d_loss_fake=0.656, g_loss=1.113
# 2/2 [==============================] - 0s 4ms/step
# >5, 82/390, d_loss_real=0.512, d_loss_fake=0.556, g_loss=1.095
# 2/2 [==============================] - 0s 3ms/step
# >5, 83/390, d_loss_real=0.523, d_loss_fake=0.701, g_loss=1.061
# 2/2 [==============================] - 0s 4ms/step
# >5, 84/390, d_loss_real=0.607, d_loss_fake=0.653, g_loss=1.088
# 2/2 [==============================] - 0s 4ms/step
# >5, 85/390, d_loss_real=0.658, d_loss_fake=0.675, g_loss=1.119
# 2/2 [==============================] - 0s 4ms/step
# >5, 86/390, d_loss_real=0.658, d_loss_fake=0.693, g_loss=1.152
# 2/2 [==============================] - 0s 5ms/step
# >5, 87/390, d_loss_real=0.770, d_loss_fake=0.651, g_loss=1.113
# 2/2 [==============================] - 0s 4ms/step
# >5, 88/390, d_loss_real=0.682, d_loss_fake=0.632, g_loss=1.043
# 2/2 [==============================] - 0s 4ms/step
# >5, 89/390, d_loss_real=0.708, d_loss_fake=0.630, g_loss=1.095
# 2/2 [==============================] - 0s 5ms/step
# >5, 90/390, d_loss_real=0.690, d_loss_fake=0.590, g_loss=1.179
# 2/2 [==============================] - 0s 5ms/step
# >5, 91/390, d_loss_real=0.765, d_loss_fake=0.575, g_loss=1.194
# 2/2 [==============================] - 0s 5ms/step
# >5, 92/390, d_loss_real=0.736, d_loss_fake=0.579, g_loss=1.211
# 2/2 [==============================] - 0s 4ms/step
# >5, 93/390, d_loss_real=0.780, d_loss_fake=0.556, g_loss=1.174
# 2/2 [==============================] - 0s 4ms/step
# >5, 94/390, d_loss_real=0.761, d_loss_fake=0.505, g_loss=1.182
# 2/2 [==============================] - 0s 5ms/step
# >5, 95/390, d_loss_real=0.690, d_loss_fake=0.538, g_loss=1.166
# 2/2 [==============================] - 0s 4ms/step
# >5, 96/390, d_loss_real=0.631, d_loss_fake=0.472, g_loss=1.159
# 2/2 [==============================] - 0s 4ms/step
# >5, 97/390, d_loss_real=0.684, d_loss_fake=0.513, g_loss=1.177
# 2/2 [==============================] - 0s 4ms/step
# >5, 98/390, d_loss_real=0.633, d_loss_fake=0.483, g_loss=1.199
# 2/2 [==============================] - 0s 4ms/step
# >5, 99/390, d_loss_real=0.590, d_loss_fake=0.500, g_loss=1.170
# 2/2 [==============================] - 0s 4ms/step
# >5, 100/390, d_loss_real=0.568, d_loss_fake=0.472, g_loss=1.291
# 2/2 [==============================] - 0s 4ms/step
# >5, 101/390, d_loss_real=0.625, d_loss_fake=0.447, g_loss=1.244
# 2/2 [==============================] - 0s 5ms/step
# >5, 102/390, d_loss_real=0.541, d_loss_fake=0.456, g_loss=1.296
# 2/2 [==============================] - 0s 4ms/step
# >5, 103/390, d_loss_real=0.546, d_loss_fake=0.448, g_loss=1.355
# 2/2 [==============================] - 0s 4ms/step
# >5, 104/390, d_loss_real=0.475, d_loss_fake=0.403, g_loss=1.428
# 2/2 [==============================] - 0s 4ms/step
# >5, 105/390, d_loss_real=0.515, d_loss_fake=0.395, g_loss=1.447
# 2/2 [==============================] - 0s 5ms/step
# >5, 106/390, d_loss_real=0.470, d_loss_fake=0.386, g_loss=1.432
# 2/2 [==============================] - 0s 4ms/step
# >5, 107/390, d_loss_real=0.454, d_loss_fake=0.370, g_loss=1.406
# 2/2 [==============================] - 0s 4ms/step
# >5, 108/390, d_loss_real=0.369, d_loss_fake=0.357, g_loss=1.476
# 2/2 [==============================] - 0s 4ms/step
# >5, 109/390, d_loss_real=0.367, d_loss_fake=0.401, g_loss=1.493
# 2/2 [==============================] - 0s 5ms/step
# >5, 110/390, d_loss_real=0.390, d_loss_fake=0.424, g_loss=1.549
# 2/2 [==============================] - 0s 5ms/step
# >5, 111/390, d_loss_real=0.437, d_loss_fake=0.485, g_loss=1.609
# 2/2 [==============================] - 0s 4ms/step
# >5, 112/390, d_loss_real=0.583, d_loss_fake=0.386, g_loss=1.498
# 2/2 [==============================] - 0s 5ms/step
# >5, 113/390, d_loss_real=0.316, d_loss_fake=0.393, g_loss=1.513
# 2/2 [==============================] - 0s 5ms/step
# >5, 114/390, d_loss_real=0.464, d_loss_fake=0.430, g_loss=1.393
# 2/2 [==============================] - 0s 5ms/step
# >5, 115/390, d_loss_real=0.417, d_loss_fake=0.456, g_loss=1.397
# 2/2 [==============================] - 0s 4ms/step
# >5, 116/390, d_loss_real=0.401, d_loss_fake=0.420, g_loss=1.444
# 2/2 [==============================] - 0s 5ms/step
# >5, 117/390, d_loss_real=0.540, d_loss_fake=0.422, g_loss=1.388
# 2/2 [==============================] - 0s 5ms/step
# >5, 118/390, d_loss_real=0.437, d_loss_fake=0.521, g_loss=1.354
# 2/2 [==============================] - 0s 4ms/step
# >5, 119/390, d_loss_real=0.467, d_loss_fake=0.558, g_loss=1.391
# 2/2 [==============================] - 0s 5ms/step
# >5, 120/390, d_loss_real=0.628, d_loss_fake=0.498, g_loss=1.358
# 2/2 [==============================] - 0s 5ms/step
# >5, 121/390, d_loss_real=0.628, d_loss_fake=0.640, g_loss=1.265
# 2/2 [==============================] - 0s 4ms/step
# >5, 122/390, d_loss_real=0.685, d_loss_fake=0.684, g_loss=1.170
# 2/2 [==============================] - 0s 4ms/step
# >5, 123/390, d_loss_real=0.579, d_loss_fake=0.650, g_loss=1.256
# 2/2 [==============================] - 0s 5ms/step
# >5, 124/390, d_loss_real=0.768, d_loss_fake=0.587, g_loss=1.164
# 2/2 [==============================] - 0s 4ms/step
# >5, 125/390, d_loss_real=0.695, d_loss_fake=0.737, g_loss=1.230
# 2/2 [==============================] - 0s 5ms/step
# >5, 126/390, d_loss_real=0.740, d_loss_fake=0.636, g_loss=1.312
# 2/2 [==============================] - 0s 4ms/step
# >5, 127/390, d_loss_real=0.747, d_loss_fake=0.632, g_loss=1.279
# 2/2 [==============================] - 0s 4ms/step
# >5, 128/390, d_loss_real=0.713, d_loss_fake=0.643, g_loss=1.346
# 2/2 [==============================] - 0s 4ms/step
# >5, 129/390, d_loss_real=0.609, d_loss_fake=0.518, g_loss=1.384
# 2/2 [==============================] - 0s 3ms/step
# >5, 130/390, d_loss_real=0.697, d_loss_fake=0.619, g_loss=1.381
# 2/2 [==============================] - 0s 4ms/step
# >5, 131/390, d_loss_real=0.645, d_loss_fake=0.531, g_loss=1.455
# 2/2 [==============================] - 0s 4ms/step
# >5, 132/390, d_loss_real=0.706, d_loss_fake=0.601, g_loss=1.444
# 2/2 [==============================] - 0s 5ms/step
# >5, 133/390, d_loss_real=0.551, d_loss_fake=0.529, g_loss=1.580
# 2/2 [==============================] - 0s 5ms/step
# >5, 134/390, d_loss_real=0.557, d_loss_fake=0.423, g_loss=1.684
# 2/2 [==============================] - 0s 5ms/step
# >5, 135/390, d_loss_real=0.520, d_loss_fake=0.501, g_loss=1.608
# 2/2 [==============================] - 0s 4ms/step
# >5, 136/390, d_loss_real=0.502, d_loss_fake=0.754, g_loss=1.522
# 2/2 [==============================] - 0s 5ms/step
# >5, 137/390, d_loss_real=0.763, d_loss_fake=1.032, g_loss=1.303
# 2/2 [==============================] - 0s 5ms/step
# >5, 138/390, d_loss_real=0.691, d_loss_fake=1.163, g_loss=1.797
# 2/2 [==============================] - 0s 5ms/step
# >5, 139/390, d_loss_real=0.803, d_loss_fake=0.410, g_loss=1.795
# 2/2 [==============================] - 0s 4ms/step
# >5, 140/390, d_loss_real=0.906, d_loss_fake=0.543, g_loss=1.982
# 2/2 [==============================] - 0s 12ms/step
# >5, 141/390, d_loss_real=0.763, d_loss_fake=0.413, g_loss=2.075
# 2/2 [==============================] - 0s 4ms/step
# >5, 142/390, d_loss_real=0.806, d_loss_fake=0.318, g_loss=1.755
# 2/2 [==============================] - 0s 9ms/step
# >5, 143/390, d_loss_real=0.709, d_loss_fake=0.386, g_loss=1.514
# 2/2 [==============================] - 0s 4ms/step
# >5, 144/390, d_loss_real=0.721, d_loss_fake=0.408, g_loss=1.513
# 2/2 [==============================] - 0s 4ms/step
# >5, 145/390, d_loss_real=0.559, d_loss_fake=0.432, g_loss=1.556
# 2/2 [==============================] - 0s 7ms/step
# >5, 146/390, d_loss_real=0.516, d_loss_fake=0.338, g_loss=1.631
# 2/2 [==============================] - 0s 4ms/step
# >5, 147/390, d_loss_real=0.649, d_loss_fake=0.318, g_loss=1.618
# 2/2 [==============================] - 0s 8ms/step
# >5, 148/390, d_loss_real=0.497, d_loss_fake=0.311, g_loss=1.661
# 2/2 [==============================] - 0s 5ms/step
# >5, 149/390, d_loss_real=0.528, d_loss_fake=0.327, g_loss=1.652
# 2/2 [==============================] - 0s 4ms/step
# >5, 150/390, d_loss_real=0.442, d_loss_fake=0.426, g_loss=1.771
# 2/2 [==============================] - 0s 5ms/step
# >5, 151/390, d_loss_real=0.471, d_loss_fake=0.334, g_loss=1.727
# 2/2 [==============================] - 0s 5ms/step
# >5, 152/390, d_loss_real=0.433, d_loss_fake=0.386, g_loss=1.680
# 2/2 [==============================] - 0s 4ms/step
# >5, 153/390, d_loss_real=0.453, d_loss_fake=0.402, g_loss=1.761
# 2/2 [==============================] - 0s 5ms/step
# >5, 154/390, d_loss_real=0.501, d_loss_fake=0.371, g_loss=1.704
# 2/2 [==============================] - 0s 4ms/step
# >5, 155/390, d_loss_real=0.521, d_loss_fake=0.422, g_loss=1.584
# 2/2 [==============================] - 0s 4ms/step
# >5, 156/390, d_loss_real=0.411, d_loss_fake=0.485, g_loss=1.602
# 2/2 [==============================] - 0s 5ms/step
# >5, 157/390, d_loss_real=0.540, d_loss_fake=0.528, g_loss=1.462
# 2/2 [==============================] - 0s 4ms/step
# >5, 158/390, d_loss_real=0.483, d_loss_fake=0.544, g_loss=1.474
# 2/2 [==============================] - 0s 5ms/step
# >5, 159/390, d_loss_real=0.633, d_loss_fake=0.609, g_loss=1.338
# 2/2 [==============================] - 0s 4ms/step
# >5, 160/390, d_loss_real=0.664, d_loss_fake=0.710, g_loss=1.164
# 2/2 [==============================] - 0s 4ms/step
# >5, 161/390, d_loss_real=0.435, d_loss_fake=0.838, g_loss=0.976
# 2/2 [==============================] - 0s 4ms/step
# >5, 162/390, d_loss_real=0.534, d_loss_fake=0.703, g_loss=0.984
# 2/2 [==============================] - 0s 4ms/step
# >5, 163/390, d_loss_real=0.676, d_loss_fake=0.727, g_loss=0.993
# 2/2 [==============================] - 0s 4ms/step
# >5, 164/390, d_loss_real=0.507, d_loss_fake=0.638, g_loss=0.997
# 2/2 [==============================] - 0s 4ms/step
# >5, 165/390, d_loss_real=0.508, d_loss_fake=0.649, g_loss=1.082
# 2/2 [==============================] - 0s 3ms/step
# >5, 166/390, d_loss_real=0.469, d_loss_fake=0.549, g_loss=1.178
# 2/2 [==============================] - 0s 4ms/step
# >5, 167/390, d_loss_real=0.375, d_loss_fake=0.509, g_loss=1.325
# 2/2 [==============================] - 0s 3ms/step
# >5, 168/390, d_loss_real=0.462, d_loss_fake=0.448, g_loss=1.321
# 2/2 [==============================] - 0s 4ms/step
# >5, 169/390, d_loss_real=0.420, d_loss_fake=0.491, g_loss=1.416
# 2/2 [==============================] - 0s 4ms/step
# >5, 170/390, d_loss_real=0.353, d_loss_fake=0.512, g_loss=1.333
# 2/2 [==============================] - 0s 4ms/step
# >5, 171/390, d_loss_real=0.367, d_loss_fake=0.619, g_loss=1.386
# 2/2 [==============================] - 0s 4ms/step
# >5, 172/390, d_loss_real=0.388, d_loss_fake=0.548, g_loss=1.218
# 2/2 [==============================] - 0s 6ms/step
# >5, 173/390, d_loss_real=0.451, d_loss_fake=0.637, g_loss=1.154
# 2/2 [==============================] - 0s 12ms/step
# >5, 174/390, d_loss_real=0.697, d_loss_fake=0.715, g_loss=1.068
# 2/2 [==============================] - 0s 5ms/step
# >5, 175/390, d_loss_real=0.479, d_loss_fake=0.668, g_loss=1.119
# 2/2 [==============================] - 0s 6ms/step
# >5, 176/390, d_loss_real=0.560, d_loss_fake=0.574, g_loss=1.202
# 2/2 [==============================] - 0s 10ms/step
# >5, 177/390, d_loss_real=0.716, d_loss_fake=0.520, g_loss=1.304
# 2/2 [==============================] - 0s 5ms/step
# >5, 178/390, d_loss_real=0.717, d_loss_fake=0.445, g_loss=1.307
# 2/2 [==============================] - 0s 5ms/step
# >5, 179/390, d_loss_real=0.643, d_loss_fake=0.565, g_loss=1.311
# 2/2 [==============================] - 0s 5ms/step
# >5, 180/390, d_loss_real=0.648, d_loss_fake=0.586, g_loss=1.231
# 2/2 [==============================] - 0s 5ms/step
# >5, 181/390, d_loss_real=0.594, d_loss_fake=0.642, g_loss=1.214
# 2/2 [==============================] - 0s 4ms/step
# >5, 182/390, d_loss_real=0.696, d_loss_fake=0.611, g_loss=1.179
# 2/2 [==============================] - 0s 5ms/step
# >5, 183/390, d_loss_real=0.663, d_loss_fake=0.689, g_loss=1.166
# 2/2 [==============================] - 0s 5ms/step
# >5, 184/390, d_loss_real=0.700, d_loss_fake=0.643, g_loss=1.058
# 2/2 [==============================] - 0s 5ms/step
# >5, 185/390, d_loss_real=0.702, d_loss_fake=0.706, g_loss=1.095
# 2/2 [==============================] - 0s 5ms/step
# >5, 186/390, d_loss_real=0.703, d_loss_fake=0.590, g_loss=1.160
# 2/2 [==============================] - 0s 5ms/step
# >5, 187/390, d_loss_real=0.655, d_loss_fake=0.559, g_loss=1.146
# 2/2 [==============================] - 0s 4ms/step
# >5, 188/390, d_loss_real=0.686, d_loss_fake=0.553, g_loss=1.224
# 2/2 [==============================] - 0s 5ms/step
# >5, 189/390, d_loss_real=0.592, d_loss_fake=0.456, g_loss=1.214
# 2/2 [==============================] - 0s 4ms/step
# >5, 190/390, d_loss_real=0.631, d_loss_fake=0.480, g_loss=1.312
# 2/2 [==============================] - 0s 4ms/step
# >5, 191/390, d_loss_real=0.526, d_loss_fake=0.502, g_loss=1.440
# 2/2 [==============================] - 0s 5ms/step
# >5, 192/390, d_loss_real=0.560, d_loss_fake=0.462, g_loss=1.458
# 2/2 [==============================] - 0s 4ms/step
# >5, 193/390, d_loss_real=0.548, d_loss_fake=0.416, g_loss=1.318
# 2/2 [==============================] - 0s 5ms/step
# >5, 194/390, d_loss_real=0.462, d_loss_fake=0.452, g_loss=1.370
# 2/2 [==============================] - 0s 5ms/step
# >5, 195/390, d_loss_real=0.444, d_loss_fake=0.406, g_loss=1.417
# 2/2 [==============================] - 0s 5ms/step
# >5, 196/390, d_loss_real=0.517, d_loss_fake=0.421, g_loss=1.318
# 2/2 [==============================] - 0s 5ms/step
# >5, 197/390, d_loss_real=0.453, d_loss_fake=0.439, g_loss=1.313
# 2/2 [==============================] - 0s 5ms/step
# >5, 198/390, d_loss_real=0.469, d_loss_fake=0.491, g_loss=1.320
# 2/2 [==============================] - 0s 4ms/step
# >5, 199/390, d_loss_real=0.550, d_loss_fake=0.553, g_loss=1.180
# 2/2 [==============================] - 0s 5ms/step
# >5, 200/390, d_loss_real=0.461, d_loss_fake=0.595, g_loss=1.226
# 2/2 [==============================] - 0s 6ms/step
# >5, 201/390, d_loss_real=0.598, d_loss_fake=0.624, g_loss=1.168
# 2/2 [==============================] - 0s 4ms/step
# >5, 202/390, d_loss_real=0.589, d_loss_fake=0.624, g_loss=1.219
# 2/2 [==============================] - 0s 4ms/step
# >5, 203/390, d_loss_real=0.560, d_loss_fake=0.656, g_loss=1.211
# 2/2 [==============================] - 0s 4ms/step
# >5, 204/390, d_loss_real=0.609, d_loss_fake=0.658, g_loss=1.090
# 2/2 [==============================] - 0s 5ms/step
# >5, 205/390, d_loss_real=0.688, d_loss_fake=0.594, g_loss=1.131
# 2/2 [==============================] - 0s 4ms/step
# >5, 206/390, d_loss_real=0.574, d_loss_fake=0.623, g_loss=1.132
# 2/2 [==============================] - 0s 4ms/step
# >5, 207/390, d_loss_real=0.511, d_loss_fake=0.570, g_loss=1.195
# 2/2 [==============================] - 0s 4ms/step
# >5, 208/390, d_loss_real=0.584, d_loss_fake=0.589, g_loss=1.116
# 2/2 [==============================] - 0s 5ms/step
# >5, 209/390, d_loss_real=0.558, d_loss_fake=0.624, g_loss=1.083
# 2/2 [==============================] - 0s 4ms/step
# >5, 210/390, d_loss_real=0.513, d_loss_fake=0.685, g_loss=1.099
# 2/2 [==============================] - 0s 8ms/step
# >5, 211/390, d_loss_real=0.498, d_loss_fake=0.732, g_loss=1.080
# 2/2 [==============================] - 0s 4ms/step
# >5, 212/390, d_loss_real=0.639, d_loss_fake=0.724, g_loss=1.076
# 2/2 [==============================] - 0s 5ms/step
# >5, 213/390, d_loss_real=0.602, d_loss_fake=0.718, g_loss=1.309
# 2/2 [==============================] - 0s 4ms/step
# >5, 214/390, d_loss_real=0.674, d_loss_fake=0.483, g_loss=1.348
# 2/2 [==============================] - 0s 12ms/step
# >5, 215/390, d_loss_real=0.673, d_loss_fake=0.515, g_loss=1.373
# 2/2 [==============================] - 0s 5ms/step
# >5, 216/390, d_loss_real=0.569, d_loss_fake=0.553, g_loss=1.341
# 2/2 [==============================] - 0s 5ms/step
# >5, 217/390, d_loss_real=0.578, d_loss_fake=0.530, g_loss=1.448
# 2/2 [==============================] - 0s 5ms/step
# >5, 218/390, d_loss_real=0.566, d_loss_fake=0.552, g_loss=1.515
# 2/2 [==============================] - 0s 5ms/step
# >5, 219/390, d_loss_real=0.639, d_loss_fake=0.540, g_loss=1.379
# 2/2 [==============================] - 0s 4ms/step
# >5, 220/390, d_loss_real=0.597, d_loss_fake=0.614, g_loss=1.265
# 2/2 [==============================] - 0s 7ms/step
# >5, 221/390, d_loss_real=0.595, d_loss_fake=0.621, g_loss=1.193
# 2/2 [==============================] - 0s 4ms/step
# >5, 222/390, d_loss_real=0.693, d_loss_fake=0.594, g_loss=1.101
# 2/2 [==============================] - 0s 4ms/step
# >5, 223/390, d_loss_real=0.779, d_loss_fake=0.784, g_loss=1.124
# 2/2 [==============================] - 0s 5ms/step
# >5, 224/390, d_loss_real=0.608, d_loss_fake=0.624, g_loss=1.130
# 2/2 [==============================] - 0s 4ms/step
# >5, 225/390, d_loss_real=0.744, d_loss_fake=0.554, g_loss=1.179
# 2/2 [==============================] - 0s 4ms/step
# >5, 226/390, d_loss_real=0.839, d_loss_fake=0.626, g_loss=1.099
# 2/2 [==============================] - 0s 5ms/step
# >5, 227/390, d_loss_real=0.671, d_loss_fake=0.614, g_loss=1.111
# 2/2 [==============================] - 0s 4ms/step
# >5, 228/390, d_loss_real=0.785, d_loss_fake=0.614, g_loss=1.213
# 2/2 [==============================] - 0s 8ms/step
# >5, 229/390, d_loss_real=0.703, d_loss_fake=0.571, g_loss=1.203
# 2/2 [==============================] - 0s 4ms/step
# >5, 230/390, d_loss_real=0.640, d_loss_fake=0.600, g_loss=1.177
# 2/2 [==============================] - 0s 5ms/step
# >5, 231/390, d_loss_real=0.584, d_loss_fake=0.507, g_loss=1.173
# 2/2 [==============================] - 0s 4ms/step
# >5, 232/390, d_loss_real=0.620, d_loss_fake=0.569, g_loss=1.176
# 2/2 [==============================] - 0s 4ms/step
# >5, 233/390, d_loss_real=0.582, d_loss_fake=0.528, g_loss=1.196
# 2/2 [==============================] - 0s 5ms/step
# >5, 234/390, d_loss_real=0.605, d_loss_fake=0.645, g_loss=1.140
# 2/2 [==============================] - 0s 4ms/step
# >5, 235/390, d_loss_real=0.521, d_loss_fake=0.585, g_loss=1.104
# 2/2 [==============================] - 0s 4ms/step
# >5, 236/390, d_loss_real=0.653, d_loss_fake=0.586, g_loss=1.122
# 2/2 [==============================] - 0s 6ms/step
# >5, 237/390, d_loss_real=0.629, d_loss_fake=0.634, g_loss=1.064
# 2/2 [==============================] - 0s 5ms/step
# >5, 238/390, d_loss_real=0.506, d_loss_fake=0.629, g_loss=1.118
# 2/2 [==============================] - 0s 4ms/step
# >5, 239/390, d_loss_real=0.636, d_loss_fake=0.635, g_loss=1.062
# 2/2 [==============================] - 0s 4ms/step
# >5, 240/390, d_loss_real=0.640, d_loss_fake=0.647, g_loss=1.019
# 2/2 [==============================] - 0s 4ms/step
# >5, 241/390, d_loss_real=0.711, d_loss_fake=0.642, g_loss=1.016
# 2/2 [==============================] - 0s 5ms/step
# >5, 242/390, d_loss_real=0.645, d_loss_fake=0.637, g_loss=1.063
# 2/2 [==============================] - 0s 6ms/step
# >5, 243/390, d_loss_real=0.601, d_loss_fake=0.582, g_loss=1.220
# 2/2 [==============================] - 0s 4ms/step
# >5, 244/390, d_loss_real=0.659, d_loss_fake=0.571, g_loss=1.135
# 2/2 [==============================] - 0s 4ms/step
# >5, 245/390, d_loss_real=0.594, d_loss_fake=0.551, g_loss=1.106
# 2/2 [==============================] - 0s 4ms/step
# >5, 246/390, d_loss_real=0.583, d_loss_fake=0.573, g_loss=1.099
# 2/2 [==============================] - 0s 4ms/step
# >5, 247/390, d_loss_real=0.535, d_loss_fake=0.555, g_loss=1.162
# 2/2 [==============================] - 0s 4ms/step
# >5, 248/390, d_loss_real=0.514, d_loss_fake=0.533, g_loss=1.191
# 2/2 [==============================] - 0s 5ms/step
# >5, 249/390, d_loss_real=0.491, d_loss_fake=0.593, g_loss=1.223
# 2/2 [==============================] - 0s 4ms/step
# >5, 250/390, d_loss_real=0.667, d_loss_fake=0.556, g_loss=1.295
# 2/2 [==============================] - 0s 5ms/step
# >5, 251/390, d_loss_real=0.699, d_loss_fake=0.442, g_loss=1.221
# 2/2 [==============================] - 0s 5ms/step
# >5, 252/390, d_loss_real=0.626, d_loss_fake=0.559, g_loss=1.114
# 2/2 [==============================] - 0s 4ms/step
# >5, 253/390, d_loss_real=0.596, d_loss_fake=0.592, g_loss=1.175
# 2/2 [==============================] - 0s 5ms/step
# >5, 254/390, d_loss_real=0.685, d_loss_fake=0.561, g_loss=1.250
# 2/2 [==============================] - 0s 4ms/step
# >5, 255/390, d_loss_real=0.602, d_loss_fake=0.600, g_loss=1.155
# 2/2 [==============================] - 0s 5ms/step
# >5, 256/390, d_loss_real=0.673, d_loss_fake=0.638, g_loss=1.086
# 2/2 [==============================] - 0s 4ms/step
# >5, 257/390, d_loss_real=0.618, d_loss_fake=0.580, g_loss=1.099
# 2/2 [==============================] - 0s 4ms/step
# >5, 258/390, d_loss_real=0.552, d_loss_fake=0.704, g_loss=1.142
# 2/2 [==============================] - 0s 5ms/step
# ...
# 2/2 [==============================] - 0s 5ms/step
# >10, 258/390, d_loss_real=0.533, d_loss_fake=0.646, g_loss=1.160
# 2/2 [==============================] - 0s 6ms/step
# >10, 259/390, d_loss_real=0.589, d_loss_fake=0.529, g_loss=1.198
# 2/2 [==============================] - 0s 4ms/step
# >10, 260/390, d_loss_real=0.643, d_loss_fake=0.493, g_loss=1.175
# 2/2 [==============================] - 0s 5ms/step
# >10, 261/390, d_loss_real=0.626, d_loss_fake=0.547, g_loss=1.249
# 2/2 [==============================] - 0s 4ms/step
# >10, 262/390, d_loss_real=0.591, d_loss_fake=0.488, g_loss=1.278
# 2/2 [==============================] - 0s 3ms/step
# >10, 263/390, d_loss_real=0.616, d_loss_fake=0.567, g_loss=1.249
# 2/2 [==============================] - 0s 5ms/step
# >10, 264/390, d_loss_real=0.670, d_loss_fake=0.478, g_loss=1.302
# 2/2 [==============================] - 0s 5ms/step
# >10, 265/390, d_loss_real=0.480, d_loss_fake=0.485, g_loss=1.359
# 2/2 [==============================] - 0s 5ms/step
# >10, 266/390, d_loss_real=0.677, d_loss_fake=0.467, g_loss=1.247
# 2/2 [==============================] - 0s 5ms/step
# >10, 267/390, d_loss_real=0.495, d_loss_fake=0.575, g_loss=1.092
# 2/2 [==============================] - 0s 4ms/step
# >10, 268/390, d_loss_real=0.690, d_loss_fake=0.780, g_loss=1.127
# 2/2 [==============================] - 0s 5ms/step
# >10, 269/390, d_loss_real=0.753, d_loss_fake=0.778, g_loss=1.143
# 2/2 [==============================] - 0s 4ms/step
# >10, 270/390, d_loss_real=0.823, d_loss_fake=0.585, g_loss=1.202
# 2/2 [==============================] - 0s 5ms/step
# >10, 271/390, d_loss_real=0.801, d_loss_fake=0.612, g_loss=1.203
# 2/2 [==============================] - 0s 4ms/step
# >10, 272/390, d_loss_real=0.656, d_loss_fake=0.488, g_loss=1.269
# 2/2 [==============================] - 0s 4ms/step
# >10, 273/390, d_loss_real=0.708, d_loss_fake=0.444, g_loss=1.268
# 2/2 [==============================] - 0s 4ms/step
# >10, 274/390, d_loss_real=0.645, d_loss_fake=0.534, g_loss=1.288
# 2/2 [==============================] - 0s 4ms/step
# >10, 275/390, d_loss_real=0.586, d_loss_fake=0.625, g_loss=1.241
# 2/2 [==============================] - 0s 5ms/step
# >10, 276/390, d_loss_real=0.712, d_loss_fake=0.578, g_loss=1.288
# 2/2 [==============================] - 0s 5ms/step
# >10, 277/390, d_loss_real=0.731, d_loss_fake=0.422, g_loss=1.314
# 2/2 [==============================] - 0s 5ms/step
# >10, 278/390, d_loss_real=0.810, d_loss_fake=0.451, g_loss=1.263
# 2/2 [==============================] - 0s 4ms/step
# >10, 279/390, d_loss_real=0.726, d_loss_fake=0.467, g_loss=1.169
# 2/2 [==============================] - 0s 4ms/step
# >10, 280/390, d_loss_real=0.683, d_loss_fake=0.509, g_loss=1.257
# 2/2 [==============================] - 0s 4ms/step
# >10, 281/390, d_loss_real=0.615, d_loss_fake=0.501, g_loss=1.187
# 2/2 [==============================] - 0s 4ms/step
# >10, 282/390, d_loss_real=0.647, d_loss_fake=0.596, g_loss=1.215
# 2/2 [==============================] - 0s 4ms/step
# >10, 283/390, d_loss_real=0.637, d_loss_fake=0.495, g_loss=1.188
# 2/2 [==============================] - 0s 5ms/step
# >10, 284/390, d_loss_real=0.658, d_loss_fake=0.518, g_loss=1.227
# 2/2 [==============================] - 0s 7ms/step
# >10, 285/390, d_loss_real=0.677, d_loss_fake=0.505, g_loss=1.191
# 2/2 [==============================] - 0s 5ms/step
# >10, 286/390, d_loss_real=0.644, d_loss_fake=0.503, g_loss=1.104
# 2/2 [==============================] - 0s 4ms/step
# >10, 287/390, d_loss_real=0.701, d_loss_fake=0.540, g_loss=1.111
# 2/2 [==============================] - 0s 4ms/step
# >10, 288/390, d_loss_real=0.623, d_loss_fake=0.576, g_loss=1.121
# 2/2 [==============================] - 0s 4ms/step
# >10, 289/390, d_loss_real=0.646, d_loss_fake=0.518, g_loss=1.096
# 2/2 [==============================] - 0s 5ms/step
# >10, 290/390, d_loss_real=0.614, d_loss_fake=0.515, g_loss=1.088
# 2/2 [==============================] - 0s 4ms/step
# >10, 291/390, d_loss_real=0.617, d_loss_fake=0.593, g_loss=1.109
# 2/2 [==============================] - 0s 4ms/step
# >10, 292/390, d_loss_real=0.600, d_loss_fake=0.532, g_loss=1.150
# 2/2 [==============================] - 0s 4ms/step
# >10, 293/390, d_loss_real=0.571, d_loss_fake=0.511, g_loss=1.152
# 2/2 [==============================] - 0s 5ms/step
# >10, 294/390, d_loss_real=0.620, d_loss_fake=0.471, g_loss=1.175
# 2/2 [==============================] - 0s 4ms/step
# >10, 295/390, d_loss_real=0.523, d_loss_fake=0.528, g_loss=1.166
# 2/2 [==============================] - 0s 4ms/step
# >10, 296/390, d_loss_real=0.477, d_loss_fake=0.467, g_loss=1.196
# 2/2 [==============================] - 0s 6ms/step
# >10, 297/390, d_loss_real=0.498, d_loss_fake=0.496, g_loss=1.208
# 2/2 [==============================] - 0s 4ms/step
# >10, 298/390, d_loss_real=0.438, d_loss_fake=0.456, g_loss=1.232
# 2/2 [==============================] - 0s 8ms/step
# >10, 299/390, d_loss_real=0.514, d_loss_fake=0.482, g_loss=1.144
# 2/2 [==============================] - 0s 5ms/step
# >10, 300/390, d_loss_real=0.453, d_loss_fake=0.513, g_loss=1.168
# 2/2 [==============================] - 0s 8ms/step
# >10, 301/390, d_loss_real=0.357, d_loss_fake=0.513, g_loss=1.227
# 2/2 [==============================] - 0s 4ms/step
# >10, 302/390, d_loss_real=0.359, d_loss_fake=0.498, g_loss=1.181
# 2/2 [==============================] - 0s 5ms/step
# >10, 303/390, d_loss_real=0.498, d_loss_fake=0.553, g_loss=1.149
# 2/2 [==============================] - 0s 6ms/step
# >10, 304/390, d_loss_real=0.469, d_loss_fake=0.544, g_loss=1.130
# 2/2 [==============================] - 0s 6ms/step
# >10, 305/390, d_loss_real=0.491, d_loss_fake=0.593, g_loss=1.128
# 2/2 [==============================] - 0s 6ms/step
# >10, 306/390, d_loss_real=0.564, d_loss_fake=0.580, g_loss=1.122
# 2/2 [==============================] - 0s 4ms/step
# >10, 307/390, d_loss_real=0.537, d_loss_fake=0.595, g_loss=1.154
# 2/2 [==============================] - 0s 8ms/step
# >10, 308/390, d_loss_real=0.777, d_loss_fake=0.647, g_loss=1.145
# 2/2 [==============================] - 0s 5ms/step
# >10, 309/390, d_loss_real=0.705, d_loss_fake=0.614, g_loss=1.214
# 2/2 [==============================] - 0s 6ms/step
# >10, 310/390, d_loss_real=0.661, d_loss_fake=0.525, g_loss=1.270
# 2/2 [==============================] - 0s 5ms/step
# >10, 311/390, d_loss_real=0.729, d_loss_fake=0.650, g_loss=1.120
# 2/2 [==============================] - 0s 5ms/step
# >10, 312/390, d_loss_real=0.703, d_loss_fake=0.551, g_loss=1.013
# 2/2 [==============================] - 0s 5ms/step
# >10, 313/390, d_loss_real=0.616, d_loss_fake=0.625, g_loss=1.046
# 2/2 [==============================] - 0s 4ms/step
# >10, 314/390, d_loss_real=0.565, d_loss_fake=0.678, g_loss=1.198
# 2/2 [==============================] - 0s 4ms/step
# >10, 315/390, d_loss_real=0.727, d_loss_fake=0.511, g_loss=1.184
# 2/2 [==============================] - 0s 4ms/step
# >10, 316/390, d_loss_real=0.658, d_loss_fake=0.503, g_loss=1.160
# 2/2 [==============================] - 0s 5ms/step
# >10, 317/390, d_loss_real=0.527, d_loss_fake=0.578, g_loss=1.111
# 2/2 [==============================] - 0s 5ms/step
# >10, 318/390, d_loss_real=0.520, d_loss_fake=0.620, g_loss=1.181
# 2/2 [==============================] - 0s 5ms/step
# >10, 319/390, d_loss_real=0.603, d_loss_fake=0.524, g_loss=1.146
# 2/2 [==============================] - 0s 5ms/step
# >10, 320/390, d_loss_real=0.638, d_loss_fake=0.686, g_loss=1.071
# 2/2 [==============================] - 0s 5ms/step
# >10, 321/390, d_loss_real=0.559, d_loss_fake=0.599, g_loss=1.145
# 2/2 [==============================] - 0s 5ms/step
# >10, 322/390, d_loss_real=0.595, d_loss_fake=0.544, g_loss=1.165
# 2/2 [==============================] - 0s 5ms/step
# >10, 323/390, d_loss_real=0.552, d_loss_fake=0.520, g_loss=1.273
# 2/2 [==============================] - 0s 5ms/step
# >10, 324/390, d_loss_real=0.535, d_loss_fake=0.510, g_loss=1.410
# 2/2 [==============================] - 0s 5ms/step
# >10, 325/390, d_loss_real=0.572, d_loss_fake=0.553, g_loss=1.433
# 2/2 [==============================] - 0s 6ms/step
# >10, 326/390, d_loss_real=0.633, d_loss_fake=0.491, g_loss=1.432
# 2/2 [==============================] - 0s 5ms/step
# >10, 327/390, d_loss_real=0.568, d_loss_fake=0.484, g_loss=1.503
# 2/2 [==============================] - 0s 5ms/step
# >10, 328/390, d_loss_real=0.647, d_loss_fake=0.498, g_loss=1.480
# 2/2 [==============================] - 0s 4ms/step
# >10, 329/390, d_loss_real=0.518, d_loss_fake=0.483, g_loss=1.425
# 2/2 [==============================] - 0s 5ms/step
# >10, 330/390, d_loss_real=0.590, d_loss_fake=0.504, g_loss=1.473
# 2/2 [==============================] - 0s 4ms/step
# >10, 331/390, d_loss_real=0.632, d_loss_fake=0.441, g_loss=1.369
# 2/2 [==============================] - 0s 5ms/step
# >10, 332/390, d_loss_real=0.620, d_loss_fake=0.541, g_loss=1.307
# 2/2 [==============================] - 0s 5ms/step
# >10, 333/390, d_loss_real=0.666, d_loss_fake=0.566, g_loss=1.275
# 2/2 [==============================] - 0s 4ms/step
# >10, 334/390, d_loss_real=0.549, d_loss_fake=0.550, g_loss=1.357
# 2/2 [==============================] - 0s 4ms/step
# >10, 335/390, d_loss_real=0.664, d_loss_fake=0.454, g_loss=1.340
# 2/2 [==============================] - 0s 5ms/step
# >10, 336/390, d_loss_real=0.646, d_loss_fake=0.534, g_loss=1.268
# 2/2 [==============================] - 0s 5ms/step
# >10, 337/390, d_loss_real=0.627, d_loss_fake=0.544, g_loss=1.262
# 2/2 [==============================] - 0s 4ms/step
# >10, 338/390, d_loss_real=0.531, d_loss_fake=0.471, g_loss=1.397
# 2/2 [==============================] - 0s 5ms/step
# >10, 339/390, d_loss_real=0.698, d_loss_fake=0.384, g_loss=1.399
# 2/2 [==============================] - 0s 4ms/step
# >10, 340/390, d_loss_real=0.622, d_loss_fake=0.520, g_loss=1.380
# 2/2 [==============================] - 0s 4ms/step
# >10, 341/390, d_loss_real=0.688, d_loss_fake=0.478, g_loss=1.345
# 2/2 [==============================] - 0s 5ms/step
# >10, 342/390, d_loss_real=0.613, d_loss_fake=0.454, g_loss=1.379
# 2/2 [==============================] - 0s 5ms/step
# >10, 343/390, d_loss_real=0.552, d_loss_fake=0.410, g_loss=1.346
# 2/2 [==============================] - 0s 4ms/step
# >10, 344/390, d_loss_real=0.566, d_loss_fake=0.457, g_loss=1.333
# 2/2 [==============================] - 0s 5ms/step
# >10, 345/390, d_loss_real=0.558, d_loss_fake=0.539, g_loss=1.287
# 2/2 [==============================] - 0s 4ms/step
# >10, 346/390, d_loss_real=0.504, d_loss_fake=0.517, g_loss=1.414
# 2/2 [==============================] - 0s 5ms/step
# >10, 347/390, d_loss_real=0.574, d_loss_fake=0.385, g_loss=1.349
# 2/2 [==============================] - 0s 5ms/step
# >10, 348/390, d_loss_real=0.574, d_loss_fake=0.485, g_loss=1.365
# 2/2 [==============================] - 0s 4ms/step
# >10, 349/390, d_loss_real=0.540, d_loss_fake=0.436, g_loss=1.422
# 2/2 [==============================] - 0s 4ms/step
# >10, 350/390, d_loss_real=0.562, d_loss_fake=0.545, g_loss=1.494
# 2/2 [==============================] - 0s 11ms/step
# >10, 351/390, d_loss_real=0.482, d_loss_fake=0.421, g_loss=1.522
# 2/2 [==============================] - 0s 5ms/step
# >10, 352/390, d_loss_real=0.565, d_loss_fake=0.381, g_loss=1.501
# 2/2 [==============================] - 0s 4ms/step
# >10, 353/390, d_loss_real=0.447, d_loss_fake=0.382, g_loss=1.489
# 2/2 [==============================] - 0s 4ms/step
# >10, 354/390, d_loss_real=0.341, d_loss_fake=0.442, g_loss=1.548
# 2/2 [==============================] - 0s 5ms/step
# >10, 355/390, d_loss_real=0.320, d_loss_fake=0.377, g_loss=1.491
# 2/2 [==============================] - 0s 4ms/step
# >10, 356/390, d_loss_real=0.333, d_loss_fake=0.410, g_loss=1.365
# 2/2 [==============================] - 0s 5ms/step
# >10, 357/390, d_loss_real=0.363, d_loss_fake=0.560, g_loss=1.326
# 2/2 [==============================] - 0s 4ms/step
# >10, 358/390, d_loss_real=0.387, d_loss_fake=0.487, g_loss=1.416
# 2/2 [==============================] - 0s 4ms/step
# >10, 359/390, d_loss_real=0.469, d_loss_fake=0.645, g_loss=1.429
# 2/2 [==============================] - 0s 5ms/step
# >10, 360/390, d_loss_real=0.570, d_loss_fake=0.387, g_loss=1.480
# 2/2 [==============================] - 0s 5ms/step
# >10, 361/390, d_loss_real=0.549, d_loss_fake=0.511, g_loss=1.452
# 2/2 [==============================] - 0s 4ms/step
# >10, 362/390, d_loss_real=0.464, d_loss_fake=0.543, g_loss=1.562
# 2/2 [==============================] - 0s 5ms/step
# >10, 363/390, d_loss_real=0.674, d_loss_fake=0.558, g_loss=1.598
# 2/2 [==============================] - 0s 7ms/step
# >10, 364/390, d_loss_real=0.738, d_loss_fake=0.321, g_loss=1.432
# 2/2 [==============================] - 0s 4ms/step
# >10, 365/390, d_loss_real=0.795, d_loss_fake=0.421, g_loss=1.342
# 2/2 [==============================] - 0s 4ms/step
# >10, 366/390, d_loss_real=0.632, d_loss_fake=0.520, g_loss=1.570
# 2/2 [==============================] - 0s 10ms/step
# >10, 367/390, d_loss_real=0.617, d_loss_fake=0.433, g_loss=1.607
# 2/2 [==============================] - 0s 6ms/step
# >10, 368/390, d_loss_real=0.560, d_loss_fake=0.426, g_loss=1.605
# 2/2 [==============================] - 0s 19ms/step
# >10, 369/390, d_loss_real=0.414, d_loss_fake=0.392, g_loss=1.510
# 2/2 [==============================] - 0s 5ms/step
# >10, 370/390, d_loss_real=0.569, d_loss_fake=0.452, g_loss=1.392
# 2/2 [==============================] - 0s 5ms/step
# >10, 371/390, d_loss_real=0.534, d_loss_fake=0.552, g_loss=1.205
# 2/2 [==============================] - 0s 5ms/step
# >10, 372/390, d_loss_real=0.459, d_loss_fake=0.659, g_loss=1.295
# 2/2 [==============================] - 0s 5ms/step
# >10, 373/390, d_loss_real=0.409, d_loss_fake=0.524, g_loss=1.321
# 2/2 [==============================] - 0s 6ms/step
# >10, 374/390, d_loss_real=0.523, d_loss_fake=0.533, g_loss=1.383
# 2/2 [==============================] - 0s 7ms/step
# >10, 375/390, d_loss_real=0.596, d_loss_fake=0.484, g_loss=1.337
# 2/2 [==============================] - 0s 6ms/step
# >10, 376/390, d_loss_real=0.509, d_loss_fake=0.544, g_loss=1.285
# 2/2 [==============================] - 0s 6ms/step
# >10, 377/390, d_loss_real=0.586, d_loss_fake=0.924, g_loss=1.359
# 2/2 [==============================] - 0s 5ms/step
# >10, 378/390, d_loss_real=0.756, d_loss_fake=0.739, g_loss=1.381
# 2/2 [==============================] - 0s 5ms/step
# >10, 379/390, d_loss_real=0.805, d_loss_fake=0.593, g_loss=1.212
# 2/2 [==============================] - 0s 6ms/step
# >10, 380/390, d_loss_real=0.813, d_loss_fake=0.703, g_loss=1.069
# 2/2 [==============================] - 0s 5ms/step
# >10, 381/390, d_loss_real=0.772, d_loss_fake=0.655, g_loss=0.995
# 2/2 [==============================] - 0s 5ms/step
# >10, 382/390, d_loss_real=0.743, d_loss_fake=0.671, g_loss=1.041
# 2/2 [==============================] - 0s 4ms/step
# >10, 383/390, d_loss_real=0.881, d_loss_fake=0.702, g_loss=1.180
# 2/2 [==============================] - 0s 4ms/step
# >10, 384/390, d_loss_real=0.724, d_loss_fake=0.596, g_loss=1.337
# 2/2 [==============================] - 0s 4ms/step
# >10, 385/390, d_loss_real=0.768, d_loss_fake=0.617, g_loss=1.483
# 2/2 [==============================] - 0s 5ms/step
# >10, 386/390, d_loss_real=0.811, d_loss_fake=0.334, g_loss=1.451
# 2/2 [==============================] - 0s 5ms/step
# >10, 387/390, d_loss_real=0.804, d_loss_fake=0.396, g_loss=1.366
# 2/2 [==============================] - 0s 5ms/step
# >10, 388/390, d_loss_real=0.618, d_loss_fake=0.424, g_loss=1.248
# 2/2 [==============================] - 0s 6ms/step
# >10, 389/390, d_loss_real=0.649, d_loss_fake=0.491, g_loss=1.267
# 2/2 [==============================] - 0s 4ms/step
# >10, 390/390, d_loss_real=0.568, d_loss_fake=0.515, g_loss=1.239
# 5/5 [==============================] - 0s 54ms/step
# >Accuracy real: 56%, fake: 89%
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def create_plot(examples, n):
    """
    Plot a grid of the generated images.

    Parameters:
    - examples: numpy array, the generated images to be plotted.
    - n: int, the dimension of the grid to display (e.g., n=3 for a 3x3 grid).
    """
    # Plot images in a grid of 'n x n'
    for i in range(n * n):
        # Define subplot
        pyplot.subplot(n, n, 1 + i)

        # Turn off axis to focus on the images
        pyplot.axis('off')

        # Plot raw pixel data
        pyplot.imshow(examples[i, :, :])

    # Display the plot
    pyplot.show()

# %%
# Generate images
latent_points = generate_latent_points(100, 100)
X = g_model.predict(latent_points)
X = (X + 1)/ 2.0

# Plot a 10x10 grid of the generated images
create_plot(X, 10)
# Out:
# 4/4 [==============================] - 0s 50ms/step
